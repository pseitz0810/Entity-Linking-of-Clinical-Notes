# %%
import numpy as np
import pandas as pd
import json

import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, Trainer, TrainingArguments
from datasets import Dataset
from seqeval.metrics import f1_score, precision_score, recall_score, classification_report, accuracy_score, performance_measure
from seqeval.scheme import IOB1, IOB2
# from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import KFold

from helpers import *

# %%
#Read in Notes for training and test set
all_notes = pd.read_csv('mimic-iv_notes_training_set.csv',index_col='note_id')
all_annotations = pd.read_csv('train_annotations.csv',index_col='note_id')
print("# of Notes:",len(all_notes))
# Out:
# # of Notes: 204

# %%
# Set the seed for train/eval/test split
rng = np.random.default_rng(seed=42)
shuffled_indices = rng.permutation(len(all_notes))

# Split notes
train_notes = all_notes.iloc[shuffled_indices[:184],:] #~90%
eval_notes = all_notes.iloc[shuffled_indices[184:194],:] #~5%
test_notes = all_notes.iloc[shuffled_indices[194:],:] #~5%

# Add annotations to each dataset
train_notes_with_annotations = pd.merge(left=train_notes,right=all_annotations,how='left',left_index=True,right_index=True)
eval_notes_with_annotations = pd.merge(left=eval_notes,right=all_annotations,how='left',left_index=True,right_index=True)
test_notes_with_annotations = pd.merge(left=test_notes,right=all_annotations,how='left',left_index=True,right_index=True)

print('Train notes:',len(train_notes),': # of Annotations:',train_notes_with_annotations.shape)
print('Eval notes:',len(eval_notes),': # of Annotations:',eval_notes_with_annotations.shape)
print('Test notes:',len(test_notes),': # of Annotations:',test_notes_with_annotations.shape)
# Out:
# Train notes: 184 : # of Annotations: (46955, 4)
# Eval notes: 10 : # of Annotations: (2709, 4)
# Test notes: 10 : # of Annotations: (1910, 4)

# %%
# model_names = ['bert-base-cased',"dmis-lab/biobert-large-cased-v1.1","microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext",
#                "cambridgeltl/SapBERT-from-PubMedBERT-fulltext"]
model_names = ["microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext"]

scores = pd.DataFrame(columns=['model','char_f1','char_f1_2','accuracy','accuracy_2'])

scores = scores.set_index('model')
MAX_LEN = 512

evaluation_range = len(train_notes)
for i in model_names:
    print('--------------------------')
    print(i)
    tokenizer = AutoTokenizer.from_pretrained(i, model_max_length=MAX_LEN)

    train_tokens, train_token_array, train_map_token_to_char, train_orig_char_array = tokenize_and_label_3label(train_notes,train_notes_with_annotations,tokenizer,use_overflow=True)
    eval_tokens, eval_token_array, eval_map_token_to_char, eval_orig_char_array = tokenize_and_label_3label(eval_notes,eval_notes_with_annotations,tokenizer,use_overflow=True)
    test_tokens, test_token_array, test_map_token_to_char, test_orig_char_array = tokenize_and_label_3label(test_notes,test_notes_with_annotations,tokenizer,use_overflow=True)
    
    label_list = ['O','B-TERM','I-TERM']
    label_to_num = {label: i for i, label in enumerate(label_list)}
    num_to_label = {i: label for i, label in enumerate(label_list)}
    NUM_LABELS = len(label_list)

    # learning_rates = [1e-4,5e-5,5e-6]
    learning_rates = [5e-5]
    for lr in learning_rates:
        training_args = TrainingArguments(
            output_dir="./results",
            evaluation_strategy="epoch",
            logging_strategy="epoch",
            num_train_epochs=10,
            learning_rate=lr,
            save_strategy='epoch',
            load_best_model_at_end=True,
            metric_for_best_model='loss'
        )

        device = "cuda:0" if torch.cuda.is_available() else "cpu"

        model = AutoModelForTokenClassification.from_pretrained(i, num_labels=NUM_LABELS)
        model = model.to(device)

        cols = list(train_tokens.columns)
        cols.remove('offset_mapping')
        train_data = Dataset.from_dict(train_tokens[cols])
        eval_data = Dataset.from_dict(eval_tokens[cols])

        trainer = Trainer(
            model=model,
            args=training_args,
            train_dataset=train_data,
            eval_dataset=eval_data,
            tokenizer=tokenizer
        )



        print('Training...')
        trainer.train()

        print('Evaluating...')
        y_pred = []
        y_pred_overflow = []
        all_predicitions = {note_id:[] for note_id in list(test_notes.index)}
        for j in range(len(test_notes)):
            one_input = tokenizer(list(test_notes['text'].values)[j], padding='max_length',
                                    truncation=True, return_tensors="pt").to(device)
            res = model(**one_input).logits.argmax(-1)[0]
            y_pred.append(res)
            all_predicitions[list(test_notes.index)[j]].extend(res)
            for o in one_input[0].overflowing:
                overflow_input = {}
                overflow_input['input_ids'] = torch.as_tensor([o.ids]).to(device)
                if 'token_type_ids' in list(one_input.keys()):
                    overflow_input['token_type_ids'] = torch.as_tensor([o.type_ids]).to(device)
                overflow_input['attention_mask'] = torch.as_tensor([o.attention_mask]).to(device)
                res = model(**overflow_input).logits.argmax(-1)[0]
                y_pred_overflow.append(res)
                all_predicitions[list(test_notes.index)[j]].extend(res)

        combined_model_res = y_pred + y_pred_overflow

        train_annotations = {note_id:[] for note_id in list(train_notes.index)}

        for batch_input in train_tokens.iterrows():
            one_note_annotations = []
            start_token = -1
            end_token = -1

            for j,t in enumerate(batch_input[1]['labels']):
                if t > 0:
                    if start_token == -1:
                        start_token = j

                    end_token = j

                    if j == len(batch_input[1]['labels'])-1 or batch_input[1]['labels'][j+1] in [0,1]:
                        one_note_annotations.append({train_notes.loc[batch_input[0],'text'][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]]:
                                                    [batch_input[1]['offset_mapping'][start_token][0],batch_input[1]['offset_mapping'][end_token][1]]})
                        start_token = -1
                        end_token = -1

            train_annotations[batch_input[0]].extend(one_note_annotations)

        true_annotations = {note_id:[] for note_id in list(test_notes.index)}
        pred_annotations = {note_id:[] for note_id in list(test_notes.index)}
        true_char_array = {note_id:np.zeros(len(test_notes.loc[note_id,'text']),dtype=np.int32) for note_id in list(test_notes.index)}
        true_char_array_2 = {note_id:np.zeros(len(test_notes.loc[note_id,'text']),dtype=np.int32) for note_id in list(test_notes.index)}
        pred_char_array = {note_id:np.zeros(len(test_notes.loc[note_id,'text']),dtype=np.int32) for note_id in list(test_notes.index)}
        pred_char_array_2 = {note_id:np.zeros(len(test_notes.loc[note_id,'text']),dtype=np.int32) for note_id in list(test_notes.index)}
        num = 0
        for batch_input in test_tokens.iterrows():
            ## Get TRUE Annotations
            one_note_annotations = []
            start_token = -1
            end_token = -1
            for j,t in enumerate(batch_input[1]['labels']):
                if t > 0:
                    if start_token == -1:
                        start_token = j

                    end_token = j

                    if j == len(batch_input[1]['labels'])-1 or batch_input[1]['labels'][j+1] in [0,1]:
                        one_note_annotations.append({test_notes.loc[batch_input[0],'text'][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]]:
                                                    [batch_input[1]['offset_mapping'][start_token][0],batch_input[1]['offset_mapping'][end_token][1]]})

                        true_char_array[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]] = t
                        true_char_array_2[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]] = t
                        if t in [2]:
                            true_char_array_2[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]] = t-1
                            true_char_array[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][start_token][1]] = t-1


                        start_token = -1
                        end_token = -1

            true_annotations[batch_input[0]].extend(one_note_annotations)

            ##Get PREDICTED Annotations
            one_note_annotations = []
            start_token = -1
            end_token = -1
            for j,t in enumerate(combined_model_res[num]):
                if t > 0:
                    if start_token == -1:
                        start_token = j

                    end_token = j

                    if j == len(combined_model_res[num])-1 or combined_model_res[num][j+1] in [0,1]:
                        one_note_annotations.append({test_notes.loc[batch_input[0],'text'][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]]:
                                                    [batch_input[1]['offset_mapping'][start_token][0],batch_input[1]['offset_mapping'][end_token][1]]})

                        pred_char_array[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]] = t.cpu()
                        pred_char_array_2[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]] = t.cpu()
                        if t in [2]:
                            pred_char_array_2[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]] = t.cpu()-1
                            pred_char_array[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][start_token][1]] = t.cpu()-1

                        start_token = -1
                        end_token = -1

            pred_annotations[batch_input[0]].extend(one_note_annotations)

            num+=1

        #Evaluation
        pred_char_f1 = []
        pred_char_f1_2 = []
        for x in pred_char_array.keys():
            pred_char_f1.append([num_to_label[y] for y in pred_char_array[x]])
        for x in pred_char_array_2.keys():
            pred_char_f1_2.append([num_to_label[y] for y in pred_char_array_2[x]])
        true_char_f1 = []
        true_char_f1_2 = []
        for x in true_char_array.keys():
            true_char_f1.append([num_to_label[y] for y in true_char_array[x]])
        for x in true_char_array_2.keys():
            true_char_f1_2.append([num_to_label[y] for y in true_char_array_2[x]])

        scores.loc[i+'('+str(lr)+')','char_f1'] = f1_score(true_char_f1,pred_char_f1)
        scores.loc[i+'('+str(lr)+')','char_f1_2'] = f1_score(true_char_f1_2,pred_char_f1_2)
        scores.loc[i+'('+str(lr)+')','accuracy'] = accuracy_score(true_char_f1,pred_char_f1)
        scores.loc[i+'('+str(lr)+')','accuracy_2'] = accuracy_score(true_char_f1_2,pred_char_f1_2)
    
scores
# Out:
# --------------------------
# microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training...
#     <div>
#
#       <progress value='1210' max='1210' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1210/1210 04:26, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.228700</td>
#       <td>0.166675</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.139700</td>
#       <td>0.150730</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.113700</td>
#       <td>0.147618</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.092700</td>
#       <td>0.150095</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.077000</td>
#       <td>0.158598</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.063100</td>
#       <td>0.180432</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.052400</td>
#       <td>0.184288</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.045200</td>
#       <td>0.199561</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.039200</td>
#       <td>0.213233</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.035300</td>
#       <td>0.218792</td>
#     </tr>
#   </tbody>
# </table><p>
# Evaluating...
#                                                    Train_P(O)_Actual  \
# model
# microsoft/BiomedNLP-BiomedBERT-base-uncased-abs...               NaN
#
#                                                    P(O)_Actual P(B)_Actual  \
# model
# microsoft/BiomedNLP-BiomedBERT-base-uncased-abs...         NaN         NaN
#
#                                                    P(O) P(B)   f1 f1_strict  \
# model
# microsoft/BiomedNLP-BiomedBERT-base-uncased-abs...  NaN  NaN  NaN       NaN
#
#                                                      char_f1 char_f1_2  \
# model
# microsoft/BiomedNLP-BiomedBERT-base-uncased-abs...  0.817887  0.784401
#
#                                                    accuracy_2  accuracy
# model
# microsoft/BiomedNLP-BiomedBERT-base-uncased-abs...   0.915484  0.915484

# %%
pred_annotations
# Out:
# {'14652764-DS-17': [{'No Known': [178, 186]},
#   {'Adverse Drug Reactions': [199, 221]},
#   {'ulcerative colitis': [259, 277]},
#   {'ileostomy takedown': [322, 340]},
#   {'abdominal colectomy': [406, 425]},
#   {'laparoscopic proctectomy': [427, 451]},
#   {'diverting\nloop ileostomy': [457, 481]},
#   {'J pouch': [483, 490]},
#   {'pouch': [504, 509]},
#   {'normal': [520, 526]},
#   {'infection': [579, 588]},
#   {'bleeding': [590, 598]},
#   {'leak': [600, 604]},
#   {'procedures': [620, 630]},
#   {'Ulcerative Colitis': [712, 730]},
#   {'Lap colectomy': [737, 750]},
#   {'ileostomy': [758, 767]},
#   {'CAD': [815, 818]},
#   {'HLD': [820, 823]},
#   {'RA': [837, 839]},
#   {'DM': [840, 842]},
#   {'NAD': [888, 891]},
#   {'CV': [892, 894]},
#   {'RRR': [896, 899]},
#   {'Resp': [900, 904]},
#   {'nl': [906, 908]},
#   {'breathing effort': [909, 925]},
#   {'GI': [926, 928]},
#   {'inc': [930, 933]},
#   {'ND': [941, 943]},
#   {'NT': [945, 947]},
#   {'soft': [949, 953]},
#   {'ileostomy takedown': [1066, 1084]},
#   {'procedure': [1103, 1112]},
#   {'PACU': [1232, 1236]},
#   {'post-operative': [1292, 1306]},
#   {'tolerating a regular diet': [1388, 1413]},
#   {'passing flatus': [1415, 1429]},
#   {'stooling': [1431, 1439]},
#   {'voiding': [1442, 1449]},
#   {'ambulating independently': [1455, 1479]},
#   {'-': [1495, 1496]},
#   {'Post-Surgical Complications': [1694, 1721]},
#   {'delay': [1847, 1852]},
#   {'discharge': [1856, 1865]},
#   {'Ileostomy Takedown': [2530, 2548]},
#   {'Mental Status': [2573, 2586]},
#   {'Clear': [2588, 2593]},
#   {'Level of Consciousness': [2608, 2630]},
#   {'Alert': [2632, 2637]},
#   {'interactive': [2642, 2653]},
#   {'Activity Status': [2655, 2670]},
#   {'Ambulatory - Independent': [2672, 2696]},
#   {'ileostomy takedown': [2768, 2786]},
#   {'procedure': [2818, 2827]},
#   {'regular diet': [2893, 2905]},
#   {'passing \n \ngas': [2907, 2921]},
#   {'pain is controlled': [2931, 2949]},
#   {'pain medications': [2955, 2971]},
#   {'monitor': [3039, 3046]},
#   {'bowel function': [3052, 3066]},
#   {'bowel movement': [3107, 3121]},
#   {'bowel \nmovement': [3208, 3223]},
#   {'anesthesia': [3252, 3262]},
#   {'decrease in bowel function': [3310, 3336]},
#   {'constipation': [3373, 3385]},
#   {'loose \nstool': [3392, 3404]},
#   {'blood': [3533, 3538]},
#   {'bowel': [3544, 3549]},
#   {'loose stool': [3606, 3617]},
#   {'to': [3668, 3670]},
#   {'narcotic pain medications': [3737, 3762]},
#   {'constipation': [3804, 3816]},
#   {'an': [3830, 3832]},
#   {'stool softener': [3851, 3865]},
#   {'ileostomy takedown': [3971, 3989]},
#   {'loose stools': [4007, 4019]},
#   {'regular food': [4047, 4059]},
#   {'muscles of the sphincters': [4095, 4120]},
#   {'urgency': [4183, 4190]},
#   {'incontinence': [4212, 4224]},
#   {'advice': [4348, 4354]},
#   {'bowel movements': [4425, 4440]},
#   {'ileostomy': [4494, 4503]},
#   {'to': [4636, 4638]},
#   {'abdominal distension': [4683, 4703]},
#   {'abdominal \npain': [4716, 4731]},
#   {'nausea, vomiting': [4733, 4749]},
#   {'inability to tolerate food or liquids': [4751, 4788]},
#   {'loose stool': [4801, 4812]},
#   {'constipation': [4817, 4829]},
#   {'wound': [4852, 4857]},
#   {'ileostomy': [4872, 4881]},
#   {'sterile gauze dressing': [4927, 4949]},
#   {'wound': [4955, 4960]},
#   {'packing': [4981, 4988]},
#   {'monitor': [5024, 5031]},
#   {'incision': [5036, 5044]},
#   {'signs': [5049, 5054]},
#   {'symptoms of infection': [5059, 5080]},
#   {'redness': [5104, 5111]},
#   {'incision': [5119, 5127]},
#   {'incision': [5145, 5153]},
#   {'increased pain': [5155, 5169]},
#   {'incision': [5177, 5185]},
#   {'draining': [5192, 5200]},
#   {'drainage': [5238, 5246]},
#   {'fever': [5269, 5274]},
#   {'wound': [5436, 5441]},
#   {'apply': [5502, 5507]},
#   {'gauze \ndressing': [5514, 5529]},
#   {'surgery': [5595, 5602]},
#   {'exercise': [5726, 5734]},
#   {'pain medication': [5808, 5823]},
#   {'pain': [5928, 5932]},
#   {'Do not drink alcohol': [5989, 6009]},
#   {'while \ntaking narcotic': [6010, 6032]},
#   {'pain medication': [6033, 6048]},
#   {'do not drive \na car': [6068, 6087]},
#   {'while taking narcotic': [6088, 6109]},
#   {'pain medication': [6110, 6125]}],
#  '16441224-DS-19': [{'No Known Allergies to Drugs': [204, 231]},
#   {'chest pain': [269, 279]},
#   {'Cardiac catheterization': [324, 347]},
#   {'coronary artery \ndisease': [426, 450]},
#   {'catherization': [463, 476]},
#   {'stent': [489, 494]},
#   {'OM1': [498, 501]},
#   {'hypertension': [508, 520]},
#   {'chest pain': [539, 549]},
#   {'stabbing': [588, 596]},
#   {'chest pain': [598, 608]},
#   {'chest pain': [652, 662]},
#   {'improved': [745, 753]},
#   {'positive': [814, 822]},
#   {'stress test': [823, 834]},
#   {'catherization': [871, 884]},
#   {'Vitals': [978, 984]},
#   {'HR': [1003, 1005]},
#   {'RR': [1010, 1012]},
#   {'RA': [1025, 1027]},
#   {'pain': [1036, 1040]},
#   {'Cardiac enzymes': [1042, 1057]},
#   {'Troponin': [1081, 1089]},
#   {'blood pressure': [1136, 1150]},
#   {'HR': [1163, 1165]},
#   {'RR': [1170, 1172]},
#   {'temperature': [1178, 1189]},
#   {'respiratory rate': [1200, 1216]},
#   {'aspirin': [1248, 1255]},
#   {'allergy to aspirin': [1308, 1326]},
#   {'resting': [1382, 1389]},
#   {'ably': [1397, 1401]},
#   {'his bed': [1405, 1412]},
#   {'chest pain': [1465, 1475]},
#   {'shortness \nof breath': [1479, 1499]},
#   {'review of systems': [1510, 1527]},
#   {'stroke': [1560, 1566]},
#   {'TIA': [1569, 1572]},
#   {'deep venous thrombosis': [1574, 1596]},
#   {'pulmonary embolism': [1598, 1616]},
#   {'bleeding': [1618, 1626]},
#   {'surgery': [1643, 1650]},
#   {'myalgias': [1652, 1660]},
#   {'cough': [1662, 1667]},
#   {'hemoptysis': [1669, 1679]},
#   {'black stools': [1681, 1693]},
#   {'red stools': [1698, 1708]},
#   {'fevers': [1727, 1733]},
#   {'chills': [1735, 1741]},
#   {'rigors': [1745, 1751]},
#   {'exertion': [1757, 1765]},
#   {'buttock': [1768, 1775]},
#   {'calf pain': [1779, 1788]},
#   {'review of \nsystems': [1807, 1825]},
#   {'negative': [1831, 1839]},
#   {'pain in': [1851, 1858]},
#   {'right hand': [1863, 1873]},
#   {'fall': [1932, 1936]},
#   {'Cardiac review of systems': [1965, 1990]},
#   {'chest pain': [2006, 2016]},
#   {'lightheadedness': [2053, 2068]},
#   {'dypsnea on exertion': [2097, 2116]},
#   {'paroxysmal nocturnal dyspnea': [2118, 2146]},
#   {'orthopnea': [2148, 2157]},
#   {'ankle edema': [2160, 2171]},
#   {'palpitations': [2173, 2185]},
#   {'syncope': [2187, 2194]},
#   {'presyncope': [2198, 2208]},
#   {'CAD': [2243, 2246]},
#   {'BMS': [2251, 2254]},
#   {'OM': [2258, 2260]},
#   {'1': [2260, 2261]},
#   {'HTN': [2277, 2280]},
#   {'renal calculi': [2285, 2298]},
#   {'surgery': [2303, 2310]},
#   {'hip replacement': [2315, 2330]},
#   {'right r/t injuries': [2338, 2356]},
#   {'GSW': [2361, 2364]},
#   {'pelvis': [2368, 2374]},
#   {'femur WWII': [2375, 2385]},
#   {'left hip replacement': [2387, 2407]},
#   {'r/t war \ninjuries': [2408, 2425]},
#   {'left leg': [2427, 2435]},
#   {'right': [2452, 2457]},
#   {'BPH': [2463, 2466]},
#   {'pneumonia': [2471, 2480]},
#   {'Cardiac cath': [3974, 3986]},
#   {'coronary angiography': [4017, 4037]},
#   {'right dominant system': [4046, 4067]},
#   {'obstructive CAD': [4097, 4112]},
#   {'LMCA': [4118, 4122]},
#   {'mild \ndisease': [4127, 4140]},
#   {'LCX': [4147, 4150]},
#   {'OM1': [4151, 4154]},
#   {'stents': [4155, 4161]},
#   {'LA': [4179, 4181]},
#   {'RCA': [4186, 4189]},
#   {'moderate \ndiffuse disease': [4194, 4219]},
#   {'catheterization': [4246, 4261]},
#   {'hemodynamics': [4291, 4303]},
#   {'systemic arterial \nhypertension': [4317, 4348]},
#   {'obstructive': [4403, 4414]},
#   {'CAD': [4415, 4418]},
#   {'OM': [4427, 4429]},
#   {'stents': [4430, 4436]},
#   {'coronary artery \ndisease': [4512, 4536]},
#   {'hypertension': [4541, 4553]},
#   {'chest pain': [4572, 4582]},
#   {'positive': [4611, 4619]},
#   {'stress test': [4620, 4631]},
#   {'CORONARIES': [4641, 4651]},
#   {'CAD': [4671, 4674]},
#   {'BMS': [4686, 4689]},
#   {'OM': [4693, 4695]},
#   {'chest pain': [4720, 4730]},
#   {'stuttering \nangina': [4749, 4767]},
#   {'disease': [4784, 4791]},
#   {'stress test': [4850, 4861]},
#   {'positive': [4874, 4882]},
#   {'catherization': [4994, 5007]},
#   {'worsening': [5015, 5024]},
#   {'good': [5054, 5058]},
#   {'regimen': [5067, 5074]},
#   {'Cardiac enzymes': [5077, 5092]},
#   {'negative': [5098, 5106]},
#   {'no': [5123, 5125]},
#   {'ischemic \nchanges': [5126, 5143]},
#   {'EKG': [5157, 5160]},
#   {'Cardiac catheterization': [5162, 5185]},
#   {'no': [5216, 5218]},
#   {'lesions': [5231, 5238]},
#   {'stenosis': [5242, 5250]},
#   {'pain free': [5266, 5275]},
#   {'cardiac medications': [5348, 5367]},
#   {'primary care': [5415, 5427]},
#   {'RHYTHM': [5475, 5481]},
#   {'arrhythmias': [5504, 5515]},
#   {'Sinus bradycardia': [5517, 5534]},
#   {'degree AV block': [5545, 5560]},
#   {'bradycardia': [5597, 5608]},
#   {'dizziness': [5628, 5637]},
#   {'fatigue': [5642, 5649]},
#   {'evaluated': [5659, 5668]},
#   {'pacemaker placement': [5730, 5749]},
#   {'holter monitor': [5805, 5819]},
#   {'bradycardia': [5850, 5861]},
#   {'primary care': [5890, 5902]},
#   {'pacemaker': [5961, 5970]},
#   {'PUMP': [5992, 5996]},
#   {'No evidence': [5998, 6009]},
#   {'failure': [6013, 6020]},
#   {'exam': [6035, 6039]},
#   {'HTN': [6050, 6053]},
#   {'ly': [6183, 6185]},
#   {'BPH': [6203, 6206]},
#   {'Anemia': [6236, 6242]},
#   {'Stable': [6244, 6250]},
#   {'work-up': [6302, 6309]},
#   {'FEN': [6343, 6346]},
#   {'hydration': [6356, 6365]},
#   {'Home With Service': [7415, 7432]},
#   {'Coronary artery disease': [7477, 7500]},
#   {'Hypertension': [7504, 7516]},
#   {'Bradycardia': [7520, 7531]},
#   {'Hemodynamically stable': [7556, 7578]},
#   {'chest pain': [7580, 7590]},
#   {'chest pain': [7661, 7671]},
#   {'cardiac catheterization': [7697, 7720]},
#   {'blockages': [7747, 7756]},
#   {'irregular heart \nrhythm': [7806, 7829]},
#   {'atrial fibrillation': [7831, 7850]},
#   {'flutter': [7854, 7861]},
#   {'heart rhythm': [7872, 7884]},
#   {'regular': [7898, 7905]},
#   {'heart monitor': [7923, 7936]},
#   {'irregular \nrhythm': [8003, 8020]},
#   {'dizzy': [8095, 8100]},
#   {'take your medications': [8170, 8191]},
#   {'Call': [8244, 8248]},
#   {'medical': [8270, 8277]},
#   {'chest discomfort': [8317, 8333]},
#   {'shortness of breath': [8335, 8354]},
#   {'lightheadedness': [8357, 8372]},
#   {'dizziness': [8376, 8385]},
#   {'bleeding': [8387, 8395]},
#   {'swelling': [8397, 8405]},
#   {'pain': [8410, 8414]},
#   {'procedure site': [8423, 8437]},
#   {'groin': [8446, 8451]}],
#  '18914188-DS-20': [{'No Known Allergies to Drugs': [209, 236]},
#   {'Abdominal pain': [274, 288]},
#   {'Laparoscopic cholecystectomy': [330, 358]},
#   {'epigastric abd pain': [416, 435]},
#   {'Laboratory': [505, 515]},
#   {'biliary \nobstruction': [547, 567]},
#   {'asymptomatic': [614, 626]},
#   {'biliary colic': [657, 670]},
#   {'fever': [681, 686]},
#   {'chills': [690, 696]},
#   {'chest pain': [702, 712]},
#   {'SOB': [716, 719]},
#   {'blood with bowel movements': [752, 778]},
#   {'hemorrhoids': [803, 814]},
#   {'colonoscopy': [825, 836]},
#   {'Cardiac arrest': [884, 898]},
#   {'AICD placed': [914, 925]},
#   {'atrial fibrillation': [941, 960]},
#   {'adin': [970, 974]},
#   {'Hypertension': [979, 991]},
#   {'Pre-cancerous facial lesions': [996, 1024]},
#   {'Appendectomy': [1029, 1041]},
#   {'CABG': [1045, 1049]},
#   {'Hyperlipidemia': [1054, 1068]},
#   {'NC': [1108, 1110]},
#   {'Physical Exam': [1114, 1127]},
#   {'PE': [1129, 1131]},
#   {'RA': [1152, 1154]},
#   {'Ox4': [1157, 1160]},
#   {'NAD': [1162, 1165]},
#   {'RRR': [1166, 1169]},
#   {'CTAB': [1171, 1175]},
#   {'Abd soft': [1176, 1184]},
#   {'hernias': [1189, 1196]},
#   {'Ext': [1197, 1200]},
#   {'edema': [1204, 1209]},
#   {'LFTs': [1301, 1305]},
#   {'Ib': [1318, 1320]},
#   {'Lip': [1327, 1330]},
#   {'Tb': [1345, 1347]},
#   {'Inr': [1369, 1372]},
#   {'UA': [1379, 1381]},
#   {'RUQ US': [1449, 1455]},
#   {'gallstones': [1476, 1486]},
#   {'-distended': [1493, 1503]},
#   {'gallbladder': [1504, 1515]},
#   {'wall': [1528, 1532]},
#   {'thickening': [1534, 1544]},
#   {'edema': [1549, 1554]},
#   {'NPO': [1569, 1572]},
#   {'medications': [1577, 1588]},
#   {'pain control': [1605, 1617]},
#   {'Cardiology': [1619, 1629]},
#   {'surgery': [1663, 1670]},
#   {'restart': [1737, 1744]},
#   {'surgery': [1784, 1791]},
#   {'surgery': [1825, 1832]},
#   {'laparoscopic \ncholecystectomy': [1839, 1868]},
#   {'PACU': [1908, 1912]},
#   {'clear liquids': [1950, 1963]},
#   {'regular diet': [1995, 2007]},
#   {'IV': [2028, 2030]},
#   {'pain control': [2045, 2057]},
#   {'hemodynamically stable': [2075, 2097]},
#   {'Neuro': [2100, 2105]},
#   {'IV fluids': [2142, 2151]},
#   {'pain control': [2183, 2195]},
#   {'CV': [2199, 2201]},
#   {'stable': [2224, 2230]},
#   {'cardiovascular': [2238, 2252]},
#   {'vital signs were routinely monitored': [2266, 2302]},
#   {'Pulmonary': [2305, 2314]},
#   {'stable': [2337, 2343]},
#   {'pulmonary': [2351, 2360]},
#   {'vital signs were routinely monitored': [2374, 2410]},
#   {'Good': [2412, 2416]},
#   {'pulmonary \ntoilet': [2417, 2434]},
#   {'ambulation': [2442, 2452]},
#   {'incentive spirrometry': [2457, 2478]},
#   {'GI': [2525, 2527]},
#   {'GU': [2528, 2530]},
#   {'Post-operatively': [2536, 2552]},
#   {'a': [2580, 2581]},
#   {'clear \ndiet': [2582, 2593]},
#   {'regular diet': [2623, 2635]},
#   {'ID': [2640, 2642]},
#   {'white blood count': [2658, 2675]},
#   {'fever': [2680, 2685]},
#   {'watched for signs of infection': [2707, 2737]},
#   {'Endocrine': [2741, 2750]},
#   {'blood sugar was monitored': [2766, 2791]},
#   {'insulin': [2814, 2821]},
#   {'Hematology': [2856, 2866]},
#   {'complete blood count': [2882, 2902]},
#   {'transfusions': [2931, 2943]},
#   {'Prophylaxis': [2960, 2971]},
#   {'ambulate': [3093, 3101]},
#   {'afebrile': [3179, 3187]},
#   {'stable vital signs': [3194, 3212]},
#   {'tolerating a regular \ndiet': [3230, 3256]},
#   {'ambulating': [3258, 3268]},
#   {'voiding without assistance': [3270, 3296]},
#   {'pain was well \ncontrolled': [3302, 3327]},
#   {'teaching': [3360, 3368]},
#   {'instructions': [3384, 3396]},
#   {'discharge': [3451, 3460]},
#   {'Choledocholithiasis': [4554, 4573]},
#   {'Acute cholecystitis': [4577, 4596]},
#   {'good condition': [4635, 4649]},
#   {'Tolerating': [4652, 4662]},
#   {'regular diet': [4663, 4675]},
#   {'oral \npain medications': [4680, 4702]},
#   {'bowel function': [4717, 4731]},
#   {'chest pain': [4892, 4902]},
#   {'pressure': [4904, 4912]},
#   {'squeezing': [4914, 4923]},
#   {'tightness': [4928, 4937]},
#   {'cough': [4958, 4963]},
#   {'shortness of breath': [4965, 4984]},
#   {'wheeze': [4989, 4995]},
#   {'vomiting': [5010, 5018]},
#   {'cannot keep': [5023, 5034]},
#   {'fluids': [5040, 5046]},
#   {'medications': [5056, 5067]},
#   {'dehydrated': [5087, 5097]},
#   {'vomiting': [5115, 5123]},
#   {'diarrhea': [5125, 5133]},
#   {'Signs': [5154, 5159]},
#   {'dehydration': [5163, 5174]},
#   {'dry mouth': [5183, 5192]},
#   {'rapid \nheartbeat': [5194, 5210]},
#   {'dizzy': [5223, 5228]},
#   {'faint': [5232, 5237]},
#   {'standing': [5243, 5251]},
#   {'blood': [5263, 5268]},
#   {'dark/black material': [5272, 5291]},
#   {'vomit': [5301, 5306]},
#   {'bowel movement': [5318, 5332]},
#   {'burning': [5351, 5358]},
#   {'urinate': [5368, 5375]},
#   {'blood in your \nurine': [5382, 5402]},
#   {'discharge': [5420, 5429]},
#   {'pain': [5438, 5442]},
#   {'pain': [5545, 5549]},
#   {'chest': [5606, 5611]},
#   {'back': [5616, 5620]},
#   {'shaking': [5633, 5640]},
#   {'chills': [5641, 5647]},
#   {'fever': [5652, 5657]},
#   {'ambulate': [5996, 6004]},
#   {'drink adequate amounts of fluids': [6033, 6065]},
#   {'while taking pain \nmedications': [6195, 6225]},
#   {'increased pain': [6304, 6318]},
#   {'swelling': [6320, 6328]},
#   {'redness': [6330, 6337]},
#   {'drainage': [6342, 6350]},
#   {'incision \nsite': [6360, 6374]},
#   {'surgical incisions': [6464, 6482]},
#   {'surgery': [6730, 6737]},
#   {'weight': [6781, 6787]}],
#  '10797747-DS-20': [{'Compazine': [196, 205]},
#   {'Post dates pregnancy': [253, 273]},
#   {'c': [394, 395]},
#   {'induction of\nlabor': [396, 414]},
#   {'cervix': [436, 442]},
#   {'URI': [537, 540]},
#   {'AFM': [659, 662]},
#   {'CP': [667, 669]},
#   {'SOB': [670, 673]},
#   {'wheeze': [674, 680]},
#   {'HA': [685, 687]},
#   {'visual\nchanges': [688, 702]},
#   {'RUQ pain': [703, 711]},
#   {'u/s': [763, 766]},
#   {'LMP': [775, 778]},
#   {'RI': [795, 797]},
#   {'RPR': [798, 801]},
#   {'HBsAg': [805, 810]},
#   {'GBS': [812, 815]},
#   {'unk': [816, 819]},
#   {'S': [824, 825]},
#   {'GLT': [827, 830]},
#   {'GBS': [832, 835]},
#   {'normal': [862, 868]},
#   {'pregnancy': [894, 903]},
#   {'ultrasound': [918, 928]},
#   {'IUD\nin': [945, 951]},
#   {'ultrasound': [959, 969]},
#   {'IUD': [992, 995]},
#   {'uterus': [1017, 1023]},
#   {'uncomplicated': [1041, 1054]},
#   {'antenatal': [1055, 1064]},
#   {'trauma': [1096, 1102]},
#   {'ultrasound': [1116, 1126]},
#   {'crack cocaine use': [1185, 1202]},
#   {'pregnancy': [1212, 1221]},
#   {'domestic violence': [1239, 1256]},
#   {'pre-eclampsia': [1263, 1276]},
#   {'pregnancy': [1288, 1297]},
#   {'SVD': [1354, 1357]},
#   {'pre': [1363, 1366]},
#   {'E': [1367, 1368]},
#   {'SVD': [1379, 1382]},
#   {'SAB': [1388, 1391]},
#   {'Chlamydia': [1438, 1447]},
#   {'pap': [1468, 1471]},
#   {'LSIL': [1473, 1477]},
#   {'Asthma': [1522, 1528]},
#   {'intubation': [1546, 1556]},
#   {'ADD': [1615, 1618]},
#   {'ADHD': [1619, 1623]},
#   {'depression': [1625, 1635]},
#   {'anxiety': [1637, 1644]},
#   {'PTSD': [1646, 1650]},
#   {'bipolar': [1653, 1660]},
#   {'suicide attempts': [1676, 1692]},
#   {'Pulmonary nodule': [1695, 1711]},
#   {'PPD': [1713, 1716]},
#   {'tonsillectomy': [1755, 1768]},
#   {'drainage abscess': [1771, 1787]},
#   {'R elbow': [1788, 1795]},
#   {'Exam': [1878, 1882]},
#   {'VS': [1898, 1900]},
#   {'RA': [1925, 1927]},
#   {'NARD': [1941, 1945]},
#   {'RRR': [1946, 1949]},
#   {'CTAB': [1950, 1954]},
#   {'wheezes': [1958, 1965]},
#   {'bronchial breath sounds': [1972, 1995]},
#   {'Abd': [1996, 1999]},
#   {'soft': [2000, 2004]},
#   {'gravid': [2006, 2012]},
#   {'ender': [2017, 2022]},
#   {'EFW': [2023, 2026]},
#   {'NT': [2041, 2043]},
#   {'edema': [2047, 2052]},
#   {'SVE': [2054, 2057]},
#   {'WBC': [2139, 2142]},
#   {'RBC': [2149, 2152]},
#   {'Hgb': [2159, 2162]},
#   {'Hct': [2168, 2171]},
#   {'MCH': [2186, 2189]},
#   {'MCHC': [2195, 2199]},
#   {'RDW': [2205, 2208]},
#   {'WBC': [2240, 2243]},
#   {'RBC': [2250, 2253]},
#   {'Hgb': [2260, 2263]},
#   {'Hct': [2270, 2273]},
#   {'MCH': [2288, 2291]},
#   {'MCHC': [2297, 2301]},
#   {'RDW': [2307, 2310]},
#   {'Neuts': [2342, 2347]},
#   {'Monos': [2358, 2363]},
#   {'Eos': [2368, 2371]},
#   {'Baso': [2377, 2381]},
#   {'Glucose': [2404, 2411]},
#   {'UreaN': [2415, 2420]},
#   {'Creat': [2424, 2429]},
#   {'Na': [2434, 2436]},
#   {'Cl': [2448, 2450]},
#   {'HCO3': [2455, 2459]},
#   {'AnGap': [2464, 2469]},
#   {'URINE': [2485, 2490]},
#   {'Protein': [2513, 2520]},
#   {'Glucose': [2525, 2532]},
#   {'Ketone': [2537, 2543]},
#   {'pH': [2570, 2572]},
#   {'URINE': [2599, 2604]},
#   {'Protein': [2627, 2634]},
#   {'Glucose': [2640, 2647]},
#   {'Ketone': [2652, 2658]},
#   {'pH': [2686, 2688]},
#   {'induction of \nlabor': [2775, 2794]},
#   {'induction': [2816, 2825]},
#   {'born infant': [2872, 2883]},
#   {'partum': [2918, 2924]},
#   {'pani was well controlled': [3006, 3030]},
#   {'regular diet': [3065, 3077]},
#   {'-': [3131, 3132]},
#   {'vaginal delivery': [3467, 3483]},
#   {'stable': [3508, 3514]}],
#  '16464652-DS-17': [{'Known': [179, 184]},
#   {'Adverse Drug Reactions': [197, 219]},
#   {'abdominal pain': [257, 271]},
#   {'diarrhea': [273, 281]},
#   {'DVT': [388, 391]},
#   {'hyponatremia': [393, 405]},
#   {'chronic \npancreatic abnormalitiy': [411, 443]},
#   {'lower abdominal pain': [481, 501]},
#   {'diarrhea': [506, 514]},
#   {'diarrhea': [541, 549]},
#   {'abdominal pain': [610, 624]},
#   {'constant': [633, 641]},
#   {'adiating': [648, 656]},
#   {'lower central abdomen': [669, 690]},
#   {'abdominal \npain': [696, 711]},
#   {'diarrhea': [755, 763]},
#   {'bowel movement': [792, 806]},
#   {'passing gas': [839, 850]},
#   {'able to eat and drink': [864, 885]},
#   {'fevers': [899, 905]},
#   {'chills': [907, 913]},
#   {'vomiting': [915, 923]},
#   {'hematemesis': [925, 936]},
#   {'melena': [938, 944]},
#   {'hematochezia': [946, 958]},
#   {'travel': [961, 967]},
#   {'food ingestion': [984, 998]},
#   {'therapy': [1021, 1028]},
#   {'H. Pylori': [1033, 1042]},
#   {'urinary \nhesitancy': [1071, 1089]},
#   {'dysuria': [1094, 1101]},
#   {'alcohol use': [1124, 1135]},
#   {'smoke': [1142, 1147]},
#   {'vitals': [1202, 1208]},
#   {'HR': [1221, 1223]},
#   {'BP1': [1226, 1229]},
#   {'RR': [1236, 1238]},
#   {'ra': [1247, 1249]},
#   {'Exam': [1251, 1255]},
#   {'ttp': [1281, 1284]},
#   {'rebound': [1290, 1297]},
#   {'guarding': [1298, 1306]},
#   {'Labs': [1308, 1312]},
#   {'ALT': [1326, 1329]},
#   {'AP': [1333, 1335]},
#   {'Na': [1350, 1352]},
#   {'BUN': [1359, 1362]},
#   {'WBC': [1382, 1385]},
#   {'CT abdomen': [1392, 1402]},
#   {'pancreatitis': [1411, 1423]},
#   {'tail': [1436, 1440]},
#   {'splenic vein \nthrombosis': [1459, 1483]},
#   {'IV': [1548, 1550]},
#   {'pancreatitis': [1633, 1645]},
#   {'VS': [1647, 1649]},
#   {'RA': [1693, 1695]},
#   {'abdominal pain': [1728, 1742]},
#   {'lower abdomen': [1794, 1807]},
#   {'adiating': [1813, 1821]},
#   {'vomiting': [1839, 1847]},
#   {'fevers': [1849, 1855]},
#   {'chills': [1857, 1863]},
#   {'SOB': [1868, 1871]},
#   {'weight loss': [1902, 1913]},
#   {'poor appetite': [1939, 1952]},
#   {'constipation': [2001, 2013]},
#   {'hyponatremia': [2064, 2076]},
#   {'chronic pancreatic \nabnormality': [2101, 2132]},
#   {'biopsy': [2157, 2163]},
#   {'colonoscopy': [2165, 2176]},
#   {'endoscopy': [2183, 2192]},
#   {'DVT': [2209, 2212]},
#   {'chronic lower abdominal pain': [2270, 2298]},
#   {'testicular pain': [2324, 2339]},
#   {'ROS': [2343, 2346]},
#   {'fever': [2364, 2369]},
#   {'chills': [2371, 2377]},
#   {'night sweats': [2379, 2391]},
#   {'vision \nchanges': [2393, 2408]},
#   {'shortness of breath': [2411, 2430]},
#   {'chest pain': [2432, 2442]},
#   {'vomiting': [2444, 2452]},
#   {'BRBPR': [2454, 2459]},
#   {'melena': [2462, 2468]},
#   {'hematochezia': [2470, 2482]},
#   {'dysuria': [2484, 2491]},
#   {'hematuria': [2493, 2502]},
#   {'headache': [2516, 2524]},
#   {'pancreatic mass': [2551, 2566]},
#   {'biopsy': [2571, 2577]},
#   {'colonoscopy': [2579, 2590]},
#   {'endoscopy': [2596, 2605]},
#   {'endoscopy': [2624, 2633]},
#   {'H pylori gastritis': [2641, 2659]},
#   {'triple therapy': [2664, 2678]},
#   {'DVT': [2692, 2695]},
#   {'Diabetes Mellitus': [2703, 2720]},
#   {'pancreatic': [2826, 2836]},
#   {'GI disease': [2846, 2856]},
#   {'cancer': [2859, 2865]},
#   {'autoimmune disease': [2870, 2888]},
#   {'Physical Exam': [2940, 2953]},
#   {'VS': [2977, 2979]},
#   {'rebound': [4063, 4070]},
#   {'guarding': [4075, 4083]},
#   {'Extremities': [4085, 4096]},
#   {'Warm': [4098, 4102]},
#   {'well perfused': [4107, 4120]},
#   {'2+ DP pulses': [4126, 4138]},
#   {'cyanosis': [4144, 4152]},
#   {'edema': [4154, 4159]},
#   {'excoriations': [4164, 4176]},
#   {'Neuro': [4178, 4183]},
#   {'Ox3': [4187, 4190]},
#   {'attentive': [4192, 4201]},
#   {'WBC': [4319, 4322]},
#   {'RBC': [4327, 4330]},
#   {'Hgb': [4337, 4340]},
#   {'Hct': [4347, 4350]},
#   {'MCH': [4364, 4367]},
#   {'MCHC': [4373, 4377]},
#   {'RDW': [4384, 4387]},
#   {'Neuts': [4419, 4424]},
#   {'Monos': [4434, 4439]},
#   {'Eos': [4444, 4447]},
#   {'Baso': [4453, 4457]},
#   {'Glucose': [4506, 4513]},
#   {'UreaN': [4519, 4524]},
#   {'Creat': [4528, 4533]},
#   {'Na': [4539, 4541]},
#   {'Cl': [4553, 4555]},
#   {'HCO3': [4559, 4563]},
#   {'AnGap': [4567, 4572]},
#   {'Glucose': [4594, 4601]},
#   {'UreaN': [4607, 4612]},
#   {'Creat': [4615, 4620]},
#   {'Na': [4625, 4627]},
#   {'Cl': [4640, 4642]},
#   {'HCO3': [4646, 4650]},
#   {'AnGap': [4654, 4659]},
#   {'ALT': [4681, 4684]},
#   {'AST': [4689, 4692]},
#   {'AlkPhos': [4696, 4703]},
#   {'TotBili': [4707, 4714]},
#   {'Calcium': [4767, 4774]},
#   {'Phos': [4779, 4783]},
#   {'Mg': [4788, 4790]},
#   {'Albumin': [4813, 4820]},
#   {'Calcium': [4825, 4832]},
#   {'Phos': [4837, 4841]},
#   {'Mg': [4846, 4848]},
#   {'Imaging': [4934, 4941]},
#   {'CT Abd': [4959, 4965]},
#   {'Pelv': [4966, 4970]},
#   {'Pancreatitis': [5007, 5019]},
#   {'body': [5042, 5046]},
#   {'tail of the': [5051, 5062]},
#   {'pancreas': [5064, 5072]},
#   {'pancreatic parenchymal': [5087, 5109]},
#   {'body': [5133, 5137]},
#   {'tail': [5143, 5147]},
#   {'edema': [5164, 5169]},
#   {'pancreatic necrosis': [5183, 5202]},
#   {'gland': [5236, 5241]},
#   {'pancreas': [5276, 5284]},
#   {'lesions': [5305, 5312]},
#   {'fluid collection': [5352, 5368]},
#   {'splenic vein': [5375, 5387]},
#   {'body': [5465, 5469]},
#   {'tail of the pancreas': [5474, 5494]},
#   {'solid': [5521, 5526]},
#   {'ground glass': [5531, 5543]},
#   {'nodules': [5544, 5551]},
#   {'both': [5564, 5568]},
#   {'lung\nbases': [5569, 5579]},
#   {'infection': [5603, 5612]},
#   {'chest CT': [5663, 5671]},
#   {'malignancy': [5747, 5757]},
#   {'Hct': [5837, 5840]},
#   {'Na': [5865, 5867]},
#   {'Cl': [5879, 5881]},
#   {'ALT': [5903, 5906]},
#   {'AST': [5912, 5915]},
#   {'AlkPhos': [5920, 5927]},
#   {'TotBili': [5931, 5938]},
#   {'DVT': [6001, 6004]},
#   {'diarrhea': [9438, 9446]},
#   {'weight loss': [9522, 9533]},
#   {'cancer': [9553, 9559]},
#   {'biopsy': [9589, 9595]},
#   {'lymph node': [9601, 9611]},
#   {'procedure': [9662, 9671]},
#   {'tenderness': [9766, 9776]},
#   {'your': [9784, 9788]},
#   {'bladder': [9789, 9796]},
#   {'difficulty \ninitiating urination': [9806, 9838]},
#   {'medication': [9866, 9876]},
#   {'primary': [9927, 9934]},
#   {'biopsy': [10098, 10104]}],
#  '19476699-DS-25': [{'Penicillins': [176, 187]},
#   {'morphine': [190, 198]},
#   {'Imitrex': [201, 208]},
#   {'Bright Red Blood per Rectum': [246, 273]},
#   {'Esophagogastroduodenoscopy': [314, 340]},
#   {'Colonoscopy': [343, 354]},
#   {'HFpEF': [436, 441]},
#   {'mitral valve disease': [443, 463]},
#   {'mechanical MVR': [468, 482]},
#   {'warfarin resistance': [512, 531]},
#   {'CAD': [538, 541]},
#   {'HTN': [543, 546]},
#   {'HLD': [548, 551]},
#   {'DMII': [553, 557]},
#   {'COPD': [559, 563]},
#   {'pyloric channel ulcer': [565, 586]},
#   {'GIB': [598, 601]},
#   {'bright red blood per rectum': [627, 654]},
#   {'acute on chronic diastolic heart failure exacerbation': [702, 755]},
#   {'nausea, vomiting': [814, 830]},
#   {'diarrhea': [832, 840]},
#   {'right-sided lower abdominal pain': [853, 885]},
#   {'pain worsened': [898, 911]},
#   {'CT \nabdomen/pelvis': [945, 963]},
#   {'ileocolitis': [984, 995]},
#   {'negative': [1019, 1027]},
#   {'abdominal pain': [1178, 1192]},
#   {'resolved': [1193, 1201]},
#   {'warfarin resistance': [1259, 1278]},
#   {'heparin': [1478, 1485]},
#   {'abdominal cramping': [1556, 1574]},
#   {'bright red blood per rectum': [1601, 1628]},
#   {'clots': [1634, 1639]},
#   {'bloody\nbowel movements': [1713, 1735]},
#   {'clots': [1741, 1746]},
#   {'lightheadedness': [1763, 1778]},
#   {'dizziness': [1780, 1789]},
#   {'chest pain': [1791, 1801]},
#   {'palpitations': [1803, 1815]},
#   {'shortness of breath': [1817, 1836]},
#   {'heparin': [1842, 1849]},
#   {'Hb': [1890, 1892]},
#   {'transfusion': [1933, 1944]},
#   {'transfusion': [2072, 2083]},
#   {'INR': [2085, 2088]},
#   {'cra': [2221, 2224]},
#   {'mp': [2224, 2226]},
#   {'bilateral': [2230, 2239]},
#   {'lower abdominal pain': [2240, 2260]},
#   {'pain': [2267, 2271]},
#   {'right-sided lower abdominal pain': [2307, 2339]},
#   {'nausea, vomiting': [2383, 2399]},
#   {'fevers': [2404, 2410]},
#   {'chills': [2414, 2420]},
#   {'substernal chest discomfort': [2445, 2472]},
#   {'anxiety': [2496, 2503]},
#   {'shortness \nof\nbreath': [2549, 2569]},
#   {'cough': [2573, 2578]},
#   {'Hypertension': [2639, 2651]},
#   {'Diabetes mellitus': [2654, 2671]},
#   {'Pulmonary Hypertension': [2690, 2712]},
#   {'Rheumatic heart disease': [2724, 2747]},
#   {'Paroxysmal Afib': [2750, 2765]},
#   {'Morbid obesity': [2768, 2782]},
#   {'PULM': [4354, 4358]},
#   {'CTAB': [4360, 4364]},
#   {'COR': [4366, 4369]},
#   {'RRR': [4371, 4374]},
#   {'ABD': [4395, 4398]},
#   {'Obese': [4400, 4405]},
#   {'BS+': [4407, 4410]},
#   {'soft': [4412, 4416]},
#   {'tenderness to palpation': [4418, 4441]},
#   {'RUQ': [4445, 4448]},
#   {'RLQ': [4453, 4456]},
#   {'rebound': [4466, 4473]},
#   {'guarding': [4477, 4485]},
#   {'EXTREM': [4487, 4493]},
#   {'Warm': [4495, 4499]},
#   {'well-perfused': [4501, 4514]},
#   {'edema': [4527, 4532]},
#   {'SKIN': [4535, 4539]},
#   {'Venous stasis': [4541, 4554]},
#   {'lower extremities': [4576, 4593]},
#   {'PSYCH': [4596, 4601]},
#   {'Calm mood': [4603, 4612]},
#   {'affect': [4617, 4623]},
#   {'HGB': [4691, 4694]},
#   {'T': [4706, 4707]},
#   {'PTT': [4729, 4732]},
#   {'WBC': [4757, 4760]},
#   {'RBC': [4765, 4768]},
#   {'HGB': [4775, 4778]},
#   {'HCT': [4784, 4787]},
#   {'MCH': [4802, 4805]},
#   {'MCHC': [4812, 4816]},
#   {'RDW': [4823, 4826]},
#   {'RDWSD': [4833, 4838]},
#   {'ALT': [4859, 4862]},
#   {'AST': [4872, 4875]},
#   {'LDH': [4888, 4891]},
#   {'PHOS': [4902, 4906]},
#   {'TOT BILI': [4912, 4920]},
#   {'WBC': [4977, 4980]},
#   {'RBC': [4985, 4988]},
#   {'Hgb': [4995, 4998]},
#   {'Hct': [5004, 5007]},
#   {'MCH': [5022, 5025]},
#   {'MCHC': [5032, 5036]},
#   {'RDW': [5043, 5046]},
#   {'RDWSD': [5053, 5058]},
#   {'PTT': [5095, 5098]},
#   {'EGD': [5110, 5113]},
#   {'Normal mucosa': [5130, 5143]},
#   {'esophagus': [5157, 5166]},
#   {'Erosions': [5169, 5177]},
#   {'antrum': [5185, 5191]},
#   {'Normal mucosa': [5194, 5207]},
#   {'duodenum': [5230, 5238]},
#   {'COLONOSCOPY': [5242, 5253]},
#   {'colon': [5360, 5365]},
#   {'mucosa': [5374, 5380]},
#   {'diverticulosis': [5426, 5440]},
#   {'sigmoid colon': [5448, 5461]},
#   {'No evidence': [5464, 5475]},
#   {'GI bleeding': [5486, 5497]},
#   {'HFpEF': [5567, 5572]},
#   {'mitral \nvalve disease': [5574, 5595]},
#   {'mechanical MVR': [5600, 5614]},
#   {'warfarin': [5628, 5636]},
#   {'warfarin resistance': [5645, 5664]},
#   {'CAD': [5666, 5669]},
#   {'HTN': [5671, 5674]},
#   {'HLD': [5676, 5679]},
#   {'DMII': [5681, 5685]},
#   {'COPD': [5687, 5691]},
#   {'bright red blood per rectum': [5711, 5738]},
#   {'Diverticulosis': [5742, 5756]},
#   {'GI bleed': [5758, 5766]},
#   {'acute blood loss': [5768, 5784]},
#   {'anemia': [5785, 5791]},
#   {'bright red blood per rectum': [5816, 5843]},
#   {'CT A/P with \ncontrast': [5845, 5866]},
#   {'sigmoid diverticulosis': [5888, 5910]},
#   {'Clear': [11988, 11993]},
#   {'Level of Consciousness': [12008, 12030]},
#   {'Alert': [12032, 12037]},
#   {'interactive': [12042, 12053]},
#   {'Activity Status': [12055, 12070]},
#   {'Ambulatory - requires assistance or aid': [12072, 12111]},
#   {'bleeding': [12285, 12293]},
#   {'GI \ntract': [12302, 12311]},
#   {'endoscopy': [12367, 12376]},
#   {'colonoscopy': [12381, 12392]},
#   {'bleeding': [12425, 12433]},
#   {'procedure': [12472, 12481]},
#   {'bleeding': [12515, 12523]}],
#  '11436844-DS-4': [{'mechanical fall': [223, 238]},
#   {'CAD': [323, 326]},
#   {'CABG': [331, 335]},
#   {'colon surgeries': [345, 360]},
#   {'trauma': [399, 405]},
#   {'eval': [406, 410]},
#   {'R': [415, 416]},
#   {'rib \nfractures': [421, 435]},
#   {'mechanical fall': [443, 458]},
#   {'walker': [500, 506]},
#   {'fell': [553, 557]},
#   {'right side': [567, 577]},
#   {'LOC': [586, 589]},
#   {'headstrike': [593, 603]},
#   {'laceration': [621, 631]},
#   {'R forearm': [639, 648]},
#   {'head CT \nhead': [673, 686]},
#   {'torso': [688, 693]},
#   {'abdomen': [695, 702]},
#   {'CXR': [704, 707]},
#   {'x-ray': [712, 717]},
#   {'R hand': [718, 724]},
#   {'non-displaced fractures': [741, 764]},
#   {'9th ribs': [775, 783]},
#   {'right': [787, 792]},
#   {'evaluation': [800, 810]},
#   {'NAD': [854, 857]},
#   {'breathing well on room air': [866, 892]},
#   {'breaths': [907, 914]},
#   {'pain': [972, 976]},
#   {'right flank': [988, 999]},
#   {'CHF': [1031, 1034]},
#   {'CODP': [1036, 1040]},
#   {'CKD': [1042, 1045]},
#   {'anemia': [1047, 1053]},
#   {'Physical Exam': [1137, 1150]},
#   {'R ribs': [1153, 1159]},
#   {'axillary': [1174, 1182]},
#   {'rib 9': [1207, 1212]},
#   {'flail chest': [1218, 1229]},
#   {'ecchymosis': [1234, 1244]},
#   {'Lungs clear': [1246, 1257]},
#   {'sit': [1285, 1288]},
#   {'exam': [1306, 1310]},
#   {'Head': [1312, 1316]},
#   {'NCAT': [1317, 1321]},
#   {'R forearm': [1323, 1332]},
#   {'skin': [1365, 1369]},
#   {'Physical Exam': [1382, 1395]},
#   {'VS': [1397, 1399]},
#   {'BP': [1412, 1414]},
#   {'Sitting': [1425, 1432]},
#   {'HR': [1433, 1435]},
#   {'RR': [1440, 1442]},
#   {'O2': [1447, 1449]},
#   {'Ra': [1455, 1457]},
#   {'GEN': [1459, 1462]},
#   {'A': [1464, 1465]},
#   {'Ox3': [1466, 1469]},
#   {'NAD': [1471, 1474]},
#   {'HEENT': [1475, 1480]},
#   {'atraumatic': [1482, 1492]},
#   {'MMM': [1494, 1497]},
#   {'CV': [1498, 1500]},
#   {'RRR': [1502, 1505]},
#   {'PULM': [1506, 1510]},
#   {'CTA': [1512, 1515]},
#   {'ABD': [1520, 1523]},
#   {'soft': [1525, 1529]},
#   {'non-distended': [1531, 1544]},
#   {'non-tender': [1546, 1556]},
#   {'palpation': [1560, 1569]},
#   {'EXT': [1570, 1573]},
#   {'instructions': [3894, 3906]},
#   {'Right': [5578, 5583]},
#   {'rib fractures': [5588, 5601]},
#   {'Mental Status': [5627, 5640]},
#   {'Clear': [5642, 5647]},
#   {'Level of Consciousness': [5662, 5684]},
#   {'Alert': [5686, 5691]},
#   {'interactive': [5696, 5707]},
#   {'Activity': [5709, 5717]},
#   {'Status': [5718, 5724]},
#   {'Ambulatory - Independent': [5726, 5750]},
#   {'right-sided rib fractures': [5845, 5870]},
#   {'fall': [5879, 5883]},
#   {'pain control': [5939, 5951]},
#   {'monitor': [5960, 5967]},
#   {'breathing': [5973, 5982]},
#   {'Physical Therapy': [6024, 6040]},
#   {'Physical Therapy': [6078, 6094]},
#   {'injury': [6258, 6264]},
#   {'right-sided rib fractures': [6272, 6297]},
#   {'severe pain': [6315, 6326]},
#   {'breaths': [6370, 6377]},
#   {'pain': [6394, 6398]},
#   {'pain medication': [6425, 6440]},
#   {'pain': [6475, 6479]},
#   {'to take deep breaths': [6508, 6528]},
#   {'pain medication': [6538, 6553]},
#   {'Pneumonia': [6621, 6630]},
#   {'rib fractures': [6652, 6665]},
#   {'spirometer': [6728, 6738]},
#   {'awake': [6765, 6770]},
#   {'airways': [6806, 6813]},
#   {'lungs': [6822, 6827]},
#   {'coughing up secretions': [6842, 6864]},
#   {'lungs': [6883, 6888]},
#   {'cough': [6936, 6941]},
# ...
#   {'Ambulatory - Independent': [3540, 3564]},
#   {'blood pressures': [3601, 3616]},
#   {'Headaches': [3669, 3678]},
#   {'visual changes': [3680, 3694]},
#   {'right sided upper \nabdominal pain': [3698, 3731]}],
#  '19442119-DS-15': [{'Known': [182, 187]},
#   {'Adverse Drug Reactions': [200, 222]},
#   {'Dyspnea on exertion': [260, 279]},
#   {'Left heart cath': [320, 335]},
#   {'hypertension': [393, 405]},
#   {'hyperlipidemia': [407, 421]},
#   {'chronic systolic heart failure': [424, 454]},
#   {'type 2 diabetes': [456, 471]},
#   {'valvular heart \ndisease': [473, 496]},
#   {'MRSA UTI': [509, 517]},
#   {'exertional dyspnea': [549, 567]},
#   {'congestive heart failure': [600, 624]},
#   {'acute \npulmonary edema': [625, 647]},
#   {'diuretics': [653, 662]},
#   {'evaluation': [679, 689]},
#   {'diuresis': [738, 746]},
#   {'cardiac pacer': [763, 776]},
#   {'decompensated': [781, 794]},
#   {'congestive heart failure': [796, 820]},
#   {'Echocardiogram': [822, 836]},
#   {'hypokinesis': [859, 870]},
#   {'hypokinesis': [883, 894]},
#   {'inferoseptum': [902, 914]},
#   {'aortic stenosis': [924, 939]},
#   {'mitral stenosis': [956, 971]},
#   {'pulmonary hypertension': [989, 1011]},
#   {'PA': [1027, 1029]},
#   {'cardiac catheterization': [1071, 1094]},
#   {'occlusion': [1120, 1129]},
#   {'LAD': [1137, 1140]},
#   {'stenosis': [1146, 1154]},
#   {'midcircumflex': [1162, 1175]},
#   {'RCA': [1177, 1180]},
#   {'ostial stenosis': [1191, 1206]},
#   {'obtuse marginal': [1214, 1229]},
#   {'ostial': [1230, 1236]},
#   {'stenosis': [1242, 1250]},
#   {'Fevers': [7782, 7788]},
#   {'Hypoxic resp failure': [7815, 7835]},
#   {'thoracics': [7842, 7851]},
#   {'Acute on chronic systolic CHF': [7879, 7908]},
#   {'Lasix': [7928, 7933]},
#   {'HCAP': [7938, 7942]},
#   {'IV': [7960, 7962]},
#   {'Toxic metabolic encephalopathy': [7981, 8011]},
#   {'Hyponatremia': [8014, 8026]},
#   {'Congestive Hepatopathy': [8030, 8052]},
#   {'AFib w/ RVR': [8055, 8066]},
#   {'hep': [8068, 8071]},
#   {'stable': [8096, 8102]},
#   {'Deceased': [8127, 8135]},
#   {'': [0, 0]}],
#  '15906604-DS-2': [{'Adverse Drug Reactions': [204, 226]},
#   {'Chest pain': [264, 274]},
#   {'cocaine abuse': [377, 390]},
#   {'chest pain': [416, 426]},
#   {'sharp': [460, 465]},
#   {'sternal': [470, 477]},
#   {'chest pain': [479, 489]},
#   {'radiating': [513, 522]},
#   {'worse': [524, 529]},
#   {'Pain': [554, 558]},
#   {'constant': [568, 576]},
#   {'pain': [601, 605]},
#   {'chest wall injuries': [625, 644]},
#   {'EKG': [704, 707]},
#   {'STE': [714, 717]},
#   {'ASA': [769, 772]},
#   {'negative': [778, 786]},
#   {'trop': [788, 792]},
#   {'negative': [801, 809]},
#   {'-': [811, 812]},
#   {'Pain': [819, 823]},
#   {'ved': [831, 834]},
#   {'eval': [910, 914]},
#   {'vitals': [937, 943]},
#   {'Labs': [973, 977]},
#   {'WBC': [999, 1002]},
#   {'Troponin': [1009, 1017]},
#   {'Phos': [1024, 1028]},
#   {'IV': [1063, 1065]},
#   {'Vitals': [1082, 1088]},
#   {'improvement': [1150, 1161]},
#   {'chest pain': [1165, 1175]},
#   {'fever': [1194, 1199]},
#   {'chills': [1201, 1207]},
#   {'cough': [1209, 1214]},
#   {'SOB': [1216, 1219]},
#   {'orthopnea': [1221, 1230]},
#   {'MGF': [1302, 1305]},
#   {'CAD': [1307, 1310]},
#   {'cirrhosis': [1319, 1328]},
#   {'lung cancer': [1337, 1348]},
#   {'VS': [1378, 1380]},
#   {'BP': [1389, 1391]},
#   {'HR': [1399, 1401]},
#   {'RR': [1405, 1407]},
#   {'O2 sat': [1411, 1417]},
#   {'RA': [1422, 1424]},
#   {'General': [1427, 1434]},
#   {'Well developed': [1436, 1450]},
#   {'NAD': [1459, 1462]},
#   {'HEENT': [1464, 1469]},
#   {'EOMI': [1471, 1475]},
#   {'PERRL': [1477, 1482]},
#   {'sclera anicteric': [1484, 1500]},
#   {'Neck': [1502, 1506]},
#   {'JVP not elevated': [1508, 1524]},
#   {'supple': [1526, 1532]},
#   {'LAD': [1537, 1540]},
#   {'CV': [1542, 1544]},
#   {'RRR': [1546, 1549]},
#   {'normal S1': [1551, 1560]},
#   {'S2': [1565, 1567]},
#   {'no mrg': [1569, 1575]},
#   {'Chest wall': [1577, 1587]},
#   {'tender': [1598, 1604]},
#   {'palpation': [1609, 1618]},
#   {'left': [1624, 1628]},
#   {'right margins': [1633, 1646]},
#   {'sternum': [1650, 1657]},
#   {'xyphoid \nprocess': [1662, 1678]},
#   {'Lungs': [1680, 1685]},
#   {'CTAB': [1687, 1691]},
#   {'wheezes': [1696, 1703]},
#   {'rales': [1707, 1712]},
#   {'Abdomen': [1714, 1721]},
#   {'Soft': [1723, 1727]},
#   {'nontender': [1729, 1738]},
#   {'non-distended': [1740, 1753]},
#   {'palpable': [1758, 1766]},
#   {'organomegaly': [1768, 1780]},
#   {'GU': [1782, 1784]},
#   {'foley': [1789, 1794]},
#   {'Ext': [1797, 1800]},
#   {'Warm': [1802, 1806]},
#   {'well perfused': [1808, 1821]},
#   {'edema': [1826, 1831]},
#   {'2+ DP pulses': [1833, 1845]},
#   {'General': [1859, 1866]},
#   {'Well developed': [1868, 1882]},
#   {'NAD': [1891, 1894]},
#   {'HEENT': [1896, 1901]},
#   {'EOMI': [1903, 1907]},
#   {'PERRL': [1909, 1914]},
#   {'sclera anicteric': [1916, 1932]},
#   {'Neck': [1934, 1938]},
#   {'JVP not elevated': [1940, 1956]},
#   {'supple': [1958, 1964]},
#   {'LAD': [1969, 1972]},
#   {'CV': [1974, 1976]},
#   {'RRR': [1978, 1981]},
#   {'normal S1': [1983, 1992]},
#   {'S2': [1997, 1999]},
#   {'no mr': [2001, 2006]},
#   {'g': [2006, 2007]},
#   {'Chest wall': [2009, 2019]},
#   {'tender': [2030, 2036]},
#   {'palpation': [2041, 2050]},
#   {'left': [2056, 2060]},
#   {'right margins': [2065, 2078]},
#   {'sternum': [2082, 2089]},
#   {'xyphoid \nprocess': [2094, 2110]},
#   {'Lungs': [2112, 2117]},
#   {'CTAB': [2119, 2123]},
#   {'wheezes': [2128, 2135]},
#   {'rales': [2139, 2144]},
#   {'Abdomen': [2146, 2153]},
#   {'Soft': [2155, 2159]},
#   {'nontender': [2161, 2170]},
#   {'non-distended': [2172, 2185]},
#   {'palpable': [2190, 2198]},
#   {'organomegaly': [2200, 2212]},
#   {'GU': [2214, 2216]},
#   {'foley': [2221, 2226]},
#   {'Ext': [2229, 2232]},
#   {'Warm': [2234, 2238]},
#   {'well perfused': [2240, 2253]},
#   {'edema': [2258, 2263]},
#   {'2+ DP pulses': [2265, 2277]},
#   {'WBC': [2330, 2333]},
#   {'RBC': [2340, 2343]},
#   {'Hgb': [2349, 2352]},
#   {'Hct': [2358, 2361]},
#   {'MCH': [2375, 2378]},
#   {'MCHC': [2384, 2388]},
#   {'RDW': [2394, 2397]},
#   {'Neuts': [2429, 2434]},
#   {'Lymphs': [2441, 2447]},
#   {'Monos': [2453, 2458]},
#   {'Eos': [2463, 2466]},
#   {'Bas': [2472, 2475]},
#   {'Glucose': [2499, 2506]},
#   {'UreaN': [2510, 2515]},
#   {'Creat': [2519, 2524]},
#   {'Na': [2529, 2531]},
#   {'Cl': [2543, 2545]},
#   {'HCO3': [2550, 2554]},
#   {'AnGap': [2558, 2563]},
#   {'cTropnT': [2614, 2621]},
#   {'-': [2648, 2649]},
#   {'Calcium': [2672, 2679]},
#   {'Phos': [2684, 2688]},
#   {'Mg': [2694, 2696]},
#   {'Surface Echo': [2712, 2724]},
#   {'Normal': [2742, 2748]},
#   {'biventricular regional/global systolic \nfunction': [2749, 2797]},
#   {'CTA': [2802, 2805]},
#   {'No evidence': [2815, 2826]},
#   {'acute aortic syndrome': [2830, 2851]},
#   {'Heart': [2858, 2863]},
#   {'size': [2864, 2868]},
#   {'normal': [2876, 2882]},
#   {'dilated right atrium': [2890, 2910]},
#   {'pericardial \neffusion': [2917, 2938]},
#   {'consolidation': [2956, 2969]},
#   {'nodules': [2996, 3003]},
#   {'respiratory bronchiolitis': [3019, 3044]},
#   {'smoking': [3063, 3070]},
#   {'Mild': [3082, 3086]},
#   {'paraseptal emphysema': [3087, 3107]},
#   {'-': [3139, 3140]},
#   {'cTropnT': [3145, 3152]},
#   {'cocaine abuse': [3182, 3195]},
#   {'chest pain': [3221, 3231]},
#   {'Chest Pain': [3236, 3246]},
#   {'costochondtritis': [3260, 3276]},
#   {'musculoskeletal pain': [3291, 3311]},
#   {'Pain': [3313, 3317]},
#   {'angina': [3334, 3340]},
#   {'exertion': [3373, 3381]},
#   {'improvement': [3391, 3402]},
#   {'exam': [3438, 3442]},
#   {'CAD': [3472, 3475]},
#   {'cocaine use': [3493, 3504]},
#   {'CTA': [3506, 3509]},
#   {'aortic dissection': [3529, 3546]},
#   {'PE': [3551, 3553]},
#   {'troponin': [3558, 3566]},
#   {'normal': [3595, 3601]},
#   {'surface \nECHO': [3602, 3615]},
#   {'ECG': [3638, 3641]},
#   {'ST elevations': [3662, 3675]},
#   {'normal': [3708, 3714]},
#   {'aspirin': [3754, 3761]},
#   {'pain': [3777, 3781]},
#   {'improved': [3786, 3794]},
#   {'pain': [3881, 3885]},
#   {'-inflammatory': [3890, 3903]},
#   {'Hypophosphatemia': [3914, 3930]},
#   {'MI': [4053, 4055]},
#   {'negative': [4061, 4069]},
#   {'trop x3': [4070, 4077]},
#   {'EKG': [4079, 4082]},
#   {'ord': [4095, 4098]},
#   {'J-point elevation': [4102, 4119]},
#   {'normal': [4133, 4139]},
#   {'aspirin': [4174, 4181]},
#   {'pain': [4237, 4241]},
#   {'PCP': [4274, 4277]},
#   {'Chest pain': [4985, 4995]},
#   {'Mental Status': [5020, 5033]},
#   {'Clear': [5035, 5040]},
#   {'Level of Consciousness': [5055, 5077]},
#   {'Alert': [5079, 5084]},
#   {'interactive': [5089, 5100]},
#   {'Activity Status': [5102, 5117]},
#   {'Ambulatory - Independent': [5119, 5143]},
#   {'chest pain': [5216, 5226]},
#   {'physical examination': [5243, 5263]},
#   {'EKG': [5265, 5268]},
#   {'ultrasound of your heart': [5270, 5294]},
#   {'blood \ntests': [5299, 5311]},
#   {'chest pain': [5337, 5347]},
#   {'heart \nattack': [5364, 5377]},
#   {'pain': [5384, 5388]},
#   {'inflammation': [5401, 5413]},
#   {'muscles': [5421, 5428]},
#   {'cartilage': [5433, 5442]},
#   {'pain': [5480, 5484]},
#   {'inflammation': [5511, 5523]},
#   {'primary': [5544, 5551]}]}

# %%
# data = json.dumps(pred_annotations)
# with open("3label_pred.json", "w") as file:
#     json.dump(data, file)

# %%
# model.save_pretrained('3label_NER_Final')
