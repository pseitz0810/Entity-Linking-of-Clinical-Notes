# %%
import numpy as np
import pandas as pd
import json

import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, Trainer, TrainingArguments
from datasets import Dataset
from seqeval.metrics import f1_score, precision_score, recall_score, classification_report
from seqeval.scheme import IOB1, IOB2
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
# from sklearn.model_selection import KFold

from snomed_graph import *
from helpers import *

# %%
#Read in SNOMED graph to get PROC, STRUCT, or FIND sub-hierarchy
SG = SnomedGraph.from_serialized('full_concept_graph.gml')
# Out:
# SNOMED graph has 361179 vertices and 1179749 edges

# %%
#Read in Notes for training and test set
all_notes = pd.read_csv('mimic-iv_notes_training_set.csv',index_col='note_id')
all_annotations = pd.read_csv('train_annotations.csv',index_col='note_id')
print("# of Notes:",len(all_notes))
print("# of Annotations:",len(all_annotations))
# Out:
# # of Notes: 204
# # of Annotations: 51574

# %%
# Set the seed for train/eval/test split
rng = np.random.default_rng(seed=42)
shuffled_indices = rng.permutation(len(all_notes))

# Split notes
train_notes = all_notes.iloc[shuffled_indices[:184],:] #~90%
eval_notes = all_notes.iloc[shuffled_indices[184:194],:] #~5%
test_notes = all_notes.iloc[shuffled_indices[194:],:] #~5%

#Add annotations to each dataset
train_notes_with_annotations = pd.merge(left=train_notes,right=all_annotations,how='left',left_index=True,right_index=True)
train_notes_with_annotations['annotation'] = train_notes_with_annotations.apply(lambda x: train_notes.loc[x.name,'text'][x['start']:x['end']],axis=1)
eval_notes_with_annotations = pd.merge(left=eval_notes,right=all_annotations,how='left',left_index=True,right_index=True)
eval_notes_with_annotations['annotation'] = eval_notes_with_annotations.apply(lambda x: eval_notes.loc[x.name,'text'][x['start']:x['end']],axis=1)
test_notes_with_annotations = pd.merge(left=test_notes,right=all_annotations,how='left',left_index=True,right_index=True)
test_notes_with_annotations['annotation'] = test_notes_with_annotations.apply(lambda x: test_notes.loc[x.name,'text'][x['start']:x['end']],axis=1)

print('Train notes:',len(train_notes),': # of Annotations:',train_notes_with_annotations.shape)
print('Eval notes:',len(eval_notes),': # of Annotations:',eval_notes_with_annotations.shape)
print('Test notes:',len(test_notes),': # of Annotations:',test_notes_with_annotations.shape)
# Out:
# Train notes: 184 : # of Annotations: (46955, 5)
# Eval notes: 10 : # of Annotations: (2709, 5)
# Test notes: 10 : # of Annotations: (1910, 5)

# %%
# Get SNOMED concept names for each annotation
train_notes_with_annotations['concept_fsn'] = train_notes_with_annotations['concept_id'].map(lambda x: SG.get_concept_details(x).fsn)
train_notes_with_annotations = train_notes_with_annotations.reset_index()

eval_notes_with_annotations['concept_fsn'] = eval_notes_with_annotations['concept_id'].map(lambda x: SG.get_concept_details(x).fsn)
eval_notes_with_annotations = eval_notes_with_annotations.reset_index()

test_notes_with_annotations['concept_fsn'] = test_notes_with_annotations['concept_id'].map(lambda x: SG.get_concept_details(x).fsn)
test_notes_with_annotations = test_notes_with_annotations.reset_index()

main_concepts = ['body structure','procedure','finding']

#Get main sub-hierarchy label for each annotaion
for index,row in train_notes_with_annotations.iterrows():

    ancestors = SG.get_ancestors(row['concept_id'])
    ancestors.add(SG.get_full_concept(row['concept_id']))

    
    for a in ancestors:
        for c in main_concepts:
            if re.search(r'\(([\w\s]+)\)',a.fsn) and c == re.search(r'\(([\w\s]+)\)',a.fsn).groups()[0]:
                train_notes_with_annotations.loc[index,'snomed_base'] = re.search(r'\(([\w\s]+)\)',a.fsn).groups()[0]

for index,row in eval_notes_with_annotations.iterrows():
    ancestors = SG.get_ancestors(row['concept_id'])
    ancestors.add(SG.get_full_concept(row['concept_id']))
    
    for a in ancestors:
        for c in main_concepts:
            if re.search(r'\(([\w\s]+)\)',a.fsn) and c == re.search(r'\(([\w\s]+)\)',a.fsn).groups()[0]:
                eval_notes_with_annotations.loc[index,'snomed_base'] = re.search(r'\(([\w\s]+)\)',a.fsn).groups()[0]
                
for index,row in test_notes_with_annotations.iterrows():
    ancestors = SG.get_ancestors(row['concept_id'])
    ancestors.add(SG.get_full_concept(row['concept_id']))
    
    for a in ancestors:
        for c in main_concepts:
            if re.search(r'\(([\w\s]+)\)',a.fsn) and c == re.search(r'\(([\w\s]+)\)',a.fsn).groups()[0]:
                test_notes_with_annotations.loc[index,'snomed_base'] = re.search(r'\(([\w\s]+)\)',a.fsn).groups()[0]
                
train_notes_with_annotations = train_notes_with_annotations.set_index('note_id')
eval_notes_with_annotations = eval_notes_with_annotations.set_index('note_id')
test_notes_with_annotations = test_notes_with_annotations.set_index('note_id')

train_notes_with_annotations.loc[(train_notes_with_annotations.index == '10513485-DS-7') & (train_notes_with_annotations['snomed_base'].isna()),:]
# Out:
# Empty DataFrame
# Columns: [text, start, end, concept_id, annotation, concept_fsn, snomed_base]
# Index: []

# %%
# model_names = ['bert-base-cased',"dmis-lab/biobert-large-cased-v1.1","microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext",
#                "cambridgeltl/SapBERT-from-PubMedBERT-fulltext"]
model_names = ["microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext"]
scores = pd.DataFrame(columns=['model','Train_P(O)_Actual','P(O)_Actual','P(B)_Actual','P(O)','P(B)','f1','f1_strict','char_f1','char_f1_2','accuracy_2'])
score_dict = {i:0 for i in model_names}

scores = scores.set_index('model')
MAX_LEN = 512

evaluation_range = len(train_notes)
for i in model_names:
    print('--------------------------')
    print(i)
    tokenizer = AutoTokenizer.from_pretrained(i, model_max_length=MAX_LEN)

    train_tokens, train_token_array, train_map_token_to_char, train_orig_char_array = tokenize_and_label_7label(train_notes,train_notes_with_annotations,tokenizer,use_overflow=True)
    eval_tokens, eval_token_array, eval_map_token_to_char, eval_orig_char_array = tokenize_and_label_7label(eval_notes,eval_notes_with_annotations,tokenizer,use_overflow=True)
    test_tokens, test_token_array, test_map_token_to_char, test_orig_char_array = tokenize_and_label_7label(test_notes,test_notes_with_annotations,tokenizer,use_overflow=True)
    
    label_list = ['O','B-PROC','I-PROC','B-FIND','I-FIND','B-STRUCT','I-STRUCT']
    label_to_num = {label: i for i, label in enumerate(label_list)}
    num_to_label = {i: label for i, label in enumerate(label_list)}
    NUM_LABELS = len(label_list)

    # learning_rates = [1e-4,5e-5,5e-6]
    learning_rates = [5e-5]
    for lr in learning_rates:
        print('---------',str(lr),'----------')
        training_args = TrainingArguments(
            output_dir="./results/7label",
            evaluation_strategy="epoch",
            logging_strategy="epoch",
            num_train_epochs=10,
            learning_rate=lr,
            save_strategy='epoch',
            load_best_model_at_end=True,
            metric_for_best_model='loss'
        )

        device = "cuda:0" if torch.cuda.is_available() else "cpu"

        model = AutoModelForTokenClassification.from_pretrained(i, num_labels=NUM_LABELS)
        model = model.to(device)

        cols = list(train_tokens.columns)
        cols.remove('offset_mapping')
#         cols.remove('')
        train_data = Dataset.from_dict(train_tokens[cols])
        eval_data = Dataset.from_dict(eval_tokens[cols])
        test_data = Dataset.from_dict(test_tokens[cols])

        trainer = Trainer(
            model=model,
            args=training_args,
            train_dataset=train_data,
            eval_dataset=eval_data,
            tokenizer=tokenizer
        )

        print('Training...')
        trainer.train()

        print('Evaluating...')
        y_pred = []
        y_pred_overflow = []
        all_predicitions = {note_id:[] for note_id in list(test_notes.index)}
        for j in range(len(test_notes)):
            one_input = tokenizer(list(test_notes['text'].values)[j], padding='max_length',
                                    truncation=True, return_tensors="pt").to(device)
            res = model(**one_input).logits.argmax(-1)[0]
            y_pred.append(res)
            all_predicitions[list(test_notes.index)[j]].extend(res)
            for o in one_input[0].overflowing:
                overflow_input = {}
                overflow_input['input_ids'] = torch.as_tensor([o.ids]).to(device)
                if 'token_type_ids' in list(one_input.keys()):
                    overflow_input['token_type_ids'] = torch.as_tensor([o.type_ids]).to(device)
                overflow_input['attention_mask'] = torch.as_tensor([o.attention_mask]).to(device)
                res = model(**overflow_input).logits.argmax(-1)[0]
                y_pred_overflow.append(res)
                all_predicitions[list(test_notes.index)[j]].extend(res)

        combined_model_res = y_pred + y_pred_overflow


        train_annotations = {note_id:[] for note_id in list(train_notes.index)}

        for batch_input in train_tokens.iterrows():
            one_note_annotations = []
            start_token = -1
            end_token = -1

            for j,t in enumerate(batch_input[1]['labels']):
                if t > 0:
                    if start_token == -1:
                        start_token = j

                    end_token = j

                    if j == len(batch_input[1]['labels'])-1 or batch_input[1]['labels'][j+1] in [0,1,3,5]:
                        one_note_annotations.append({train_notes.loc[batch_input[0],'text'][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]]:
                                                    [batch_input[1]['offset_mapping'][start_token][0],batch_input[1]['offset_mapping'][end_token][1]]})
                        start_token = -1
                        end_token = -1

            train_annotations[batch_input[0]].extend(one_note_annotations)

        true_annotations = {note_id:[] for note_id in list(test_notes.index)}
        pred_annotations = {note_id:[] for note_id in list(test_notes.index)}
        true_char_array = {note_id:np.zeros(len(test_notes.loc[note_id,'text']),dtype=np.int32) for note_id in list(test_notes.index)}
        true_char_array_2 = {note_id:np.zeros(len(test_notes.loc[note_id,'text']),dtype=np.int32) for note_id in list(test_notes.index)}
        pred_char_array = {note_id:np.zeros(len(test_notes.loc[note_id,'text']),dtype=np.int32) for note_id in list(test_notes.index)}
        pred_char_array_2 = {note_id:np.zeros(len(test_notes.loc[note_id,'text']),dtype=np.int32) for note_id in list(test_notes.index)}
        num = 0
        char_token_count = {k:0 for k in label_list}

        for batch_input in test_tokens.iterrows():
            ## Get TRUE Annotations
            one_note_annotations = []
            start_token = -1
            end_token = -1

            for j,t in enumerate(batch_input[1]['labels']):
                if t > 0:
                    if start_token == -1:
                        start_token = j

                    end_token = j

                    if j == len(batch_input[1]['labels'])-1 or batch_input[1]['labels'][j+1] in [0,1,3,5]:
                        one_note_annotations.append({test_notes.loc[batch_input[0],'text'][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]]:
                                                    [batch_input[1]['offset_mapping'][start_token][0],batch_input[1]['offset_mapping'][end_token][1]]})

                        true_char_array[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]] = t
                        true_char_array_2[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]] = t
                        if t in [2,4,6]:
                            true_char_array_2[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]] = t-1
                            true_char_array[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][start_token][1]] = t-1

                        start_token = -1
                        end_token = -1

            true_annotations[batch_input[0]].extend(one_note_annotations)

            ##Get PREDICTED Annotations
            one_note_annotations = []
            start_token = -1
            end_token = -1

            for j,t in enumerate(combined_model_res[num]):
                if t > 0:
                    if start_token == -1:
                        start_token = j

                    end_token = j

                    if j == len(combined_model_res[num])-1 or combined_model_res[num][j+1] in [0,1,3,5]:
                        one_note_annotations.append({test_notes.loc[batch_input[0],'text'][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]]:
                                                    [t.cpu(),[batch_input[1]['offset_mapping'][start_token][0],batch_input[1]['offset_mapping'][end_token][1]]]})

                        pred_char_array[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]] = t.cpu()
                        pred_char_array_2[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][end_token][1]] = t.cpu()
                        if t in [2,4,6]:
                            pred_char_array_2[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]] = t.cpu()-1
                            pred_char_array[batch_input[0]][batch_input[1]['offset_mapping'][start_token][0]:batch_input[1]['offset_mapping'][start_token][1]] = t.cpu()-1

                        start_token = -1
                        end_token = -1

            pred_annotations[batch_input[0]].extend(one_note_annotations)

            num += 1


        #Evaluation
        pred_char_f1 = []
        pred_char_f1_2 = []
        for x in pred_char_array.keys():
            pred_char_f1.append([num_to_label[y] for y in pred_char_array[x]])
        for x in pred_char_array_2.keys():
            pred_char_f1_2.append([num_to_label[y] for y in pred_char_array_2[x]])
        true_char_f1 = []
        true_char_f1_2 = []
        for x in true_char_array.keys():
            true_char_f1.append([num_to_label[y] for y in true_char_array[x]])
        for x in true_char_array_2.keys():
            true_char_f1_2.append([num_to_label[y] for y in true_char_array_2[x]])

        pred_label_array = []
        for x in y_pred:
            temp = []
            for y in x.cpu():
                temp.append(num_to_label[y.item()])
            pred_label_array.append(temp)
        for x in y_pred_overflow:
            temp = []
            for y in x.cpu():
                temp.append(num_to_label[y.item()])
            pred_label_array.append(temp)

        true_label_array = []
        for x in test_tokens['labels']:
            temp = []
            for y in x:
                temp.append(num_to_label[y])
            true_label_array.append(temp)

#         scores.loc[i+'('+str(lr)+')','char_f1'] = f1_score(true_char_f1,pred_char_f1)
#         scores.loc[i+'('+str(lr)+')','char_f1_2'] = f1_score(true_char_f1_2,pred_char_f1_2)
#         scores.loc[i+'('+str(lr)+')','accuracy'] = accuracy_score(true_char_f1,pred_char_f1)
#         scores.loc[i+'('+str(lr)+')','accuracy_2'] = accuracy_score(true_char_f1_2,pred_char_f1_2)

        print(classification_report(true_char_f1,pred_char_f1,mode='strict',scheme=IOB2))
        print(classification_report(true_char_f1_2,pred_char_f1_2,mode='strict',scheme=IOB2))
        score_dict[i] = classification_report(true_char_f1,pred_char_f1,mode='strict',scheme=IOB2)
    
    
# scores
# Out:
# --------------------------
# microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext
# --------- 5e-05 ----------
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training...
#     <div>
#
#       <progress value='1210' max='1210' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1210/1210 04:24, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.368100</td>
#       <td>0.201536</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.182800</td>
#       <td>0.186419</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.145400</td>
#       <td>0.177469</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.119600</td>
#       <td>0.177210</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.099000</td>
#       <td>0.181831</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.083400</td>
#       <td>0.197943</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.070600</td>
#       <td>0.206821</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.062100</td>
#       <td>0.214734</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.054700</td>
#       <td>0.218029</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.050600</td>
#       <td>0.223237</td>
#     </tr>
#   </tbody>
# </table><p>
# Evaluating...
#               precision    recall  f1-score   support
#
#         FIND       0.79      0.84      0.82      5958
#         PROC       0.77      0.75      0.76      3352
#       STRUCT       0.60      0.75      0.66       829
#
#    micro avg       0.77      0.80      0.78     10139
#    macro avg       0.72      0.78      0.75     10139
# weighted avg       0.77      0.80      0.78     10139
#
#               precision    recall  f1-score   support
#
#         FIND       0.75      0.81      0.78      3310
#         PROC       0.76      0.74      0.75      2227
#       STRUCT       0.56      0.76      0.65       580
#
#    micro avg       0.73      0.78      0.76      6117
#    macro avg       0.69      0.77      0.73      6117
# weighted avg       0.74      0.78      0.76      6117
# Empty DataFrame
# Columns: [Train_P(O)_Actual, P(O)_Actual, P(B)_Actual, P(O), P(B), f1, f1_strict, char_f1, char_f1_2, accuracy_2]
# Index: []

# %%
for note in pred_annotations:
    for i,annotation in enumerate(pred_annotations[note]):
#         print(annotation,pred_annotations[note][i][list(pred_annotations[note][i].keys())[0]][0])
        pred_annotations[note][i][list(pred_annotations[note][i].keys())[0]][0] = pred_annotations[note][i][list(pred_annotations[note][i].keys())[0]][0].item()
pred_annotations
# Out:
# {'14652764-DS-17': [{'No': [3, [178, 180]]},
#   {'Adverse Drug Reactions': [4, [199, 221]]},
#   {'ulcerative colitis': [4, [259, 277]]},
#   {'ileostomy takedown': [2, [322, 340]]},
#   {'abdominal colectomy': [2, [406, 425]]},
#   {'laparoscopic': [1, [427, 439]]},
#   {'proctectomy': [2, [440, 451]]},
#   {'diverting\nloop ileostomy': [2, [457, 481]]},
#   {'infection': [3, [579, 588]]},
#   {'bleeding': [3, [590, 598]]},
#   {'leak': [5, [600, 604]]},
#   {'procedures': [1, [620, 630]]},
#   {'Ulcerative Colitis': [4, [712, 730]]},
#   {'Lap colectomy': [2, [737, 750]]},
#   {'ileostomy': [2, [758, 767]]},
#   {'CAD': [3, [815, 818]]},
#   {'HLD': [4, [820, 823]]},
#   {'RA': [3, [837, 839]]},
#   {'DM': [3, [840, 842]]},
#   {'NAD': [3, [888, 891]]},
#   {'CV': [1, [892, 894]]},
#   {'RRR': [4, [896, 899]]},
#   {'Resp': [1, [900, 904]]},
#   {'GI': [1, [926, 928]]},
#   {'inc': [3, [930, 933]]},
#   {'ND': [3, [941, 943]]},
#   {'NT': [3, [945, 947]]},
#   {'soft': [3, [949, 953]]},
#   {'ileostomy takedown': [2, [1066, 1084]]},
#   {'procedure': [1, [1103, 1112]]},
#   {'PACU': [2, [1232, 1236]]},
#   {'post-operative': [4, [1292, 1306]]},
#   {'ating': [4, [1393, 1398]]},
#   {'regular diet': [4, [1401, 1413]]},
#   {'passing flatus': [4, [1415, 1429]]},
#   {'stooling': [4, [1431, 1439]]},
#   {'voiding': [3, [1442, 1449]]},
#   {'ambulating independently': [4, [1455, 1479]]},
#   {'follow-up': [4, [1489, 1498]]},
#   {'Post-Surgical': [4, [1694, 1707]]},
#   {'Ileostomy Takedown': [2, [2530, 2548]]},
#   {'Mental Status': [2, [2573, 2586]]},
#   {'Level of Consciousness': [2, [2608, 2630]]},
#   {'Alert': [3, [2632, 2637]]},
#   {'interactive': [3, [2642, 2653]]},
#   {'Activity Status': [4, [2655, 2670]]},
#   {'Ambulatory - Independent': [4, [2672, 2696]]},
#   {'ileostomy takedown': [2, [2768, 2786]]},
#   {'procedure': [1, [2818, 2827]]},
#   {'regular diet': [4, [2893, 2905]]},
#   {'passing \n \ngas': [4, [2907, 2921]]},
#   {'pain medications': [2, [2955, 2971]]},
#   {'anesthesia': [1, [3252, 3262]]},
#   {'decrease': [3, [3310, 3318]]},
#   {'constipation': [3, [3373, 3385]]},
#   {'loose \nstool': [4, [3392, 3404]]},
#   {'blood': [4, [3533, 3538]]},
#   {'loose stool': [4, [3606, 3617]]},
#   {'narcotic': [2, [3737, 3745]]},
#   {'pain medications': [2, [3746, 3762]]},
#   {'constipation': [3, [3804, 3816]]},
#   {'stool softener': [2, [3851, 3865]]},
#   {'ileostomy': [2, [3971, 3980]]},
#   {'frequent loose stools': [4, [3998, 4019]]},
#   {'regular food': [4, [4047, 4059]]},
#   {'improve': [3, [4080, 4087]]},
#   {'muscles': [5, [4095, 4102]]},
#   {'s': [6, [4119, 4120]]},
#   {'urgency': [3, [4183, 4190]]},
#   {'incontinence': [3, [4212, 4224]]},
#   {'improve': [3, [4245, 4252]]},
#   {'medication': [1, [4400, 4410]]},
#   {'ileostomy': [2, [4494, 4503]]},
#   {'abdominal distension': [4, [4683, 4703]]},
#   {'abdominal \npain': [4, [4716, 4731]]},
#   {'nausea, vomiting': [4, [4733, 4749]]},
#   {'inability to tolerate food or liquids': [4, [4751, 4788]]},
#   {'prolonged loose stool': [4, [4791, 4812]]},
#   {'constipation': [3, [4817, 4829]]},
#   {'wound': [4, [4852, 4857]]},
#   {'ileostomy': [2, [4872, 4881]]},
#   {'sterile gauze dressing': [2, [4927, 4949]]},
#   {'wound': [3, [4955, 4960]]},
#   {'packing': [1, [4981, 4988]]},
#   {'monitor': [1, [5024, 5031]]},
#   {'incision': [5, [5036, 5044]]},
#   {'signs and symptoms of infection': [2, [5049, 5080]]},
#   {'redness': [4, [5104, 5111]]},
#   {'incision': [5, [5119, 5127]]},
#   {'incision': [5, [5145, 5153]]},
#   {'increased pain': [4, [5155, 5169]]},
#   {'incision': [5, [5177, 5185]]},
#   {'draining': [3, [5192, 5200]]},
#   {'drainage': [5, [5238, 5246]]},
#   {'fever': [3, [5269, 5274]]},
#   {'er': [2, [5400, 5402]]},
#   {'wound': [5, [5436, 5441]]},
#   {'exercise': [1, [5726, 5734]]},
#   {'pain medication': [2, [5808, 5823]]},
#   {'pain': [1, [5928, 5932]]},
#   {'Do not drink alcohol': [2, [5989, 6009]]},
#   {'while \ntaking narcotic': [2, [6010, 6032]]},
#   {'pain medication': [2, [6033, 6048]]},
#   {'taking narcotic': [2, [6094, 6109]]},
#   {'pain medication': [2, [6110, 6125]]}],
#  '16441224-DS-19': [{'chest pain': [4, [269, 279]]},
#   {'Cardiac catheterization': [2, [324, 347]]},
#   {'coronary artery \ndisease': [4, [426, 450]]},
#   {'catherization': [2, [463, 476]]},
#   {'stent': [1, [489, 494]]},
#   {'OM': [5, [498, 500]]},
#   {'hypertension': [3, [508, 520]]},
#   {'chest pain': [4, [539, 549]]},
#   {'stabbing" chest pain': [4, [588, 608]]},
#   {'chest pain': [4, [652, 662]]},
#   {'improved': [3, [745, 753]]},
#   {'positive': [3, [814, 822]]},
#   {'stress test': [4, [823, 834]]},
#   {'catherization': [2, [871, 884]]},
#   {'Vitals': [4, [978, 984]]},
#   {'HR': [3, [1003, 1005]]},
#   {'RR': [3, [1010, 1012]]},
#   {'RA': [3, [1025, 1027]]},
#   {'no pain': [4, [1033, 1040]]},
#   {'Cardiac enzymes': [2, [1042, 1057]]},
#   {'Troponin': [1, [1081, 1089]]},
#   {'blood pressure': [4, [1136, 1150]]},
#   {'HR': [3, [1163, 1165]]},
#   {'RR': [3, [1170, 1172]]},
#   {'temperature': [3, [1178, 1189]]},
#   {'respiratory rate': [4, [1200, 1216]]},
#   {'aspirin': [1, [1248, 1255]]},
#   {'allergy': [3, [1308, 1315]]},
#   {'resting comfortably in his': [4, [1382, 1408]]},
#   {'chest pain': [4, [1465, 1475]]},
#   {'shortness \nof breath': [4, [1479, 1499]]},
#   {'review of systems': [2, [1510, 1527]]},
#   {'stroke': [3, [1560, 1566]]},
#   {'TIA': [3, [1569, 1572]]},
#   {'deep venous thrombosis': [4, [1574, 1596]]},
#   {'pulmonary embolism': [4, [1598, 1616]]},
#   {'bleeding': [3, [1618, 1626]]},
#   {'surgery': [1, [1643, 1650]]},
#   {'myalgias': [4, [1652, 1660]]},
#   {'cough': [3, [1662, 1667]]},
#   {'hemoptysis': [4, [1669, 1679]]},
#   {'black stools': [4, [1681, 1693]]},
#   {'red stools': [4, [1698, 1708]]},
#   {'fevers': [4, [1727, 1733]]},
#   {'chills': [4, [1735, 1741]]},
#   {'rigors': [4, [1745, 1751]]},
#   {'exertional': [4, [1757, 1767]]},
#   {'buttock': [4, [1768, 1775]]},
#   {'calf pain': [4, [1779, 1788]]},
#   {'review of \nsystems': [2, [1807, 1825]]},
#   {'negative': [3, [1831, 1839]]},
#   {'pain in his': [4, [1851, 1862]]},
#   {'right hand': [4, [1863, 1873]]},
#   {'fall': [3, [1932, 1936]]},
#   {'Cardiac review of systems': [2, [1965, 1990]]},
#   {'chest pain': [4, [2006, 2016]]},
#   {'lightheadedness': [4, [2053, 2068]]},
#   {'worsening': [3, [2086, 2095]]},
#   {'dypsnea on exertion': [4, [2097, 2116]]},
#   {'paroxysmal nocturnal dyspnea': [4, [2118, 2146]]},
#   {'orthopnea': [4, [2148, 2157]]},
#   {'ankle edema': [4, [2160, 2171]]},
#   {'palpitations': [4, [2173, 2185]]},
#   {'syncope': [3, [2187, 2194]]},
#   {'presyncope': [4, [2198, 2208]]},
#   {'CAD': [3, [2243, 2246]]},
#   {'BMS': [1, [2251, 2254]]},
#   {'OM': [5, [2258, 2260]]},
#   {'HTN': [3, [2277, 2280]]},
#   {'renal calculi': [4, [2285, 2298]]},
#   {'surgery': [1, [2303, 2310]]},
#   {'hip replacement': [2, [2315, 2330]]},
#   {'right r/t injuries': [4, [2338, 2356]]},
#   {'GSW': [4, [2361, 2364]]},
#   {'pelvis': [5, [2368, 2374]]},
#   {'femur': [5, [2375, 2380]]},
#   {'left hip replacement': [2, [2387, 2407]]},
#   {'r': [3, [2408, 2409]]},
#   {'t': [4, [2410, 2411]]},
#   {'war \ninjuries': [4, [2412, 2425]]},
#   {'left leg': [6, [2427, 2435]]},
#   {'right': [5, [2452, 2457]]},
#   {'BPH': [3, [2463, 2466]]},
#   {'pneumonia': [3, [2471, 2480]]},
#   {'appendectomy': [2, [2485, 2497]]},
#   {'Risk': [2, [2512, 2516]]},
#   {'Diabetes': [3, [2529, 2537]]},
#   {'Dyslipidemia': [3, [2542, 2554]]},
#   {'Hypertension': [3, [2560, 2572]]},
#   {'Percutaneous coronary intervention': [2, [2598, 2632]]},
#   {'BMS': [1, [2662, 2665]]},
#   {'OM': [5, [2673, 2675]]},
#   {'rotational atherectomy': [2, [2681, 2703]]},
#   {'cath': [1, [2722, 2726]]},
#   {'stent placement': [2, [2767, 2782]]},
#   {'coronary artery disease': [4, [2883, 2906]]},
#   {'died': [3, [2919, 2923]]},
#   {'VS': [3, [2972, 2974]]},
#   {'RA': [3, [3005, 3007]]},
#   {'GENERAL': [1, [3020, 3027]]},
#   {'sleeping': [3, [3043, 3051]]},
#   {'awake': [3, [3060, 3065]]},
#   {'NAD': [3, [3068, 3071]]},
#   {'Oriented \nx3': [4, [3073, 3085]]},
#   {'Mood': [3, [3087, 3091]]},
#   {'affect': [3, [3093, 3099]]},
#   {'HEENT': [2, [3115, 3120]]},
#   {'NC': [3, [3122, 3124]]},
#   {'Sclera anicteric': [4, [3128, 3144]]},
#   {'PERRL': [4, [3146, 3151]]},
#   {'EOMI': [4, [3153, 3157]]},
#   {'Conjunctiva': [6, [3159, 3170]]},
#   {'pallor': [4, [3186, 3192]]},
#   {'cyanosis': [4, [3196, 3204]]},
#   {'oral mucosa': [6, [3212, 3223]]},
#   {'xanthalesma': [4, [3228, 3239]]},
#   {'NECK': [1, [3244, 3248]]},
#   {'Supple': [3, [3250, 3256]]},
#   {'JVP': [4, [3262, 3265]]},
#   {'CARDIAC': [1, [3277, 3284]]},
#   {'intercostal space': [6, [3305, 3322]]},
#   {'midclavicular \nline': [6, [3324, 3343]]},
#   {'Bradycardic': [4, [3345, 3356]]},
#   {'S1': [3, [3381, 3383]]},
#   {'S2': [3, [3385, 3387]]},
#   {'No m/r/g': [4, [3389, 3397]]},
#   {'thrills': [4, [3403, 3410]]},
#   {'lifts': [4, [3412, 3417]]},
#   {'No S3': [4, [3419, 3424]]},
#   {'S4': [3, [3428, 3430]]},
#   {'LUNGS': [1, [3434, 3439]]},
#   {'chest wall deformities': [4, [3444, 3466]]},
#   {'scoliosis': [3, [3468, 3477]]},
#   {'kyphosis': [4, [3481, 3489]]},
#   {'Resp': [1, [3491, 3495]]},
#   {'accessory muscle': [4, [3516, 3532]]},
#   {'CTAB': [4, [3538, 3542]]},
#   {'crackles': [4, [3547, 3555]]},
#   {'wheezes': [4, [3558, 3565]]},
#   {'rhonchi': [4, [3569, 3576]]},
#   {'abdomen': [5, [3602, 3609]]},
#   {'nodule': [5, [3640, 3646]]},
#   {'upper back': [6, [3660, 3670]]},
#   {'ABDOMEN': [1, [3674, 3681]]},
#   {'Soft': [3, [3683, 3687]]},
#   {'ND': [3, [3691, 3693]]},
#   {'HSM': [4, [3698, 3701]]},
#   {'tenderness': [3, [3705, 3715]]},
#   {'Abd': [1, [3717, 3720]]},
#   {'aorta': [5, [3721, 3726]]},
#   {'enlarged': [5, [3732, 3740]]},
#   {'palpation': [1, [3744, 3753]]},
#   {'abdominial bruits': [4, [3758, 3775]]},
#   {'EXTREMITIES': [1, [3779, 3790]]},
#   {'femoral bruits': [4, [3805, 3819]]},
#   {'SKIN': [1, [3823, 3827]]},
#   {'stasis dermatitis': [4, [3832, 3849]]},
#   {'ulcers': [5, [3851, 3857]]},
#   {'scars': [5, [3859, 3864]]},
#   {'xanthomas': [4, [3869, 3878]]},
#   {'Carotid': [3, [3903, 3910]]},
#   {'Cardiac cath': [2, [3974, 3986]]},
#   {'coronary angiography': [2, [4017, 4037]]},
#   {'obstructive': [3, [4097, 4108]]},
#   {'CAD': [3, [4109, 4112]]},
#   {'LMCA': [6, [4118, 4122]]},
#   {'mild': [3, [4127, 4131]]},
#   {'disease': [3, [4133, 4140]]},
#   {'LCX': [6, [4147, 4150]]},
#   {'OM': [5, [4151, 4153]]},
#   {'stents': [1, [4155, 4161]]},
#   {'LA': [5, [4179, 4181]]},
#   {'RCA': [5, [4186, 4189]]},
#   {'moderate': [3, [4194, 4202]]},
#   {'diffuse disease': [4, [4204, 4219]]},
#   {'catheterization': [1, [4246, 4261]]},
#   {'systemic arterial \nhypertension': [4, [4317, 4348]]},
#   {'CAD': [3, [4415, 4418]]},
#   {'stents': [1, [4430, 4436]]},
#   {'coronary artery \ndisease': [4, [4512, 4536]]},
#   {'hypertension': [3, [4541, 4553]]},
#   {'chest pain': [4, [4572, 4582]]},
#   {'positive stress test': [4, [4611, 4631]]},
#   {'CAD': [3, [4671, 4674]]},
#   {'BMS': [1, [4686, 4689]]},
#   {'chest pain': [4, [4720, 4730]]},
#   {'stuttering \nangina': [4, [4749, 4767]]},
#   {'disease': [3, [4784, 4791]]},
#   {'stress test': [2, [4850, 4861]]},
#   {'catherization': [2, [4994, 5007]]},
#   {'Cardiac enzymes': [4, [5077, 5092]]},
#   {'no': [3, [5123, 5125]]},
#   {'ischemic \nchanges': [4, [5126, 5143]]},
#   {'EKG': [2, [5157, 5160]]},
#   {'Cardiac catheterization was': [2, [5162, 5189]]},
#   {'no': [3, [5216, 5218]]},
#   {'lesions': [5, [5231, 5238]]},
#   {'stenosis': [5, [5242, 5250]]},
#   {'pain free': [4, [5266, 5275]]},
#   {'cardiac': [1, [5348, 5355]]},
#   {'up': [4, [5403, 5405]]},
#   {'primary': [1, [5415, 5422]]},
#   {'RHYTHM': [3, [5475, 5481]]},
#   {'arrhythmias': [3, [5504, 5515]]},
#   {'Sinus bradycardia': [4, [5517, 5534]]},
#   {'degree AV block': [4, [5545, 5560]]},
#   {'bradycardia': [3, [5597, 5608]]},
#   {'dizziness': [3, [5628, 5637]]},
#   {'fatigue': [3, [5642, 5649]]},
#   {'evaluated': [1, [5659, 5668]]},
#   {'pacemaker placement': [2, [5730, 5749]]},
#   {'bradycardia': [3, [5850, 5861]]},
#   {'primary': [1, [5890, 5897]]},
#   {'pacemaker': [1, [5961, 5970]]},
#   {'evidence': [4, [6001, 6009]]},
#   {'exam': [1, [6035, 6039]]},
#   {'HTN': [3, [6050, 6053]]},
#   {'BPH': [3, [6203, 6206]]},
#   {'Anemia': [3, [6236, 6242]]},
#   {'Stable': [3, [6244, 6250]]},
#   {'work-up': [2, [6302, 6309]]},
#   {'hydration': [1, [6356, 6365]]},
#   {'Home With Service': [2, [7415, 7432]]},
#   {'Coronary artery disease': [4, [7477, 7500]]},
#   {'Hypertension': [3, [7504, 7516]]},
#   {'Bradycardia': [3, [7520, 7531]]},
#   {'Hemodynamically stable': [4, [7556, 7578]]},
#   {'chest pain free': [4, [7580, 7595]]},
#   {'chest pain': [4, [7661, 7671]]},
#   {'cardiac catheterization': [2, [7697, 7720]]},
#   {'blockage': [5, [7747, 7755]]},
#   {'irregular heart \nrhythm': [4, [7806, 7829]]},
#   {'atrial fibrillation': [4, [7831, 7850]]},
#   {'flutter': [4, [7854, 7861]]},
#   {'heart rhythm': [4, [7872, 7884]]},
#   {'regular': [4, [7898, 7905]]},
#   {'heart monitor': [2, [7923, 7936]]},
#   {'irregular \nrhythm': [4, [8003, 8020]]},
#   {'dizzy': [4, [8095, 8100]]},
#   {'your medications as': [2, [8175, 8194]]},
#   {'Call your doctor': [2, [8244, 8260]]},
#   {'medical attention': [2, [8270, 8287]]},
#   {'chest discomfort': [4, [8317, 8333]]},
#   {'shortness of breath': [4, [8335, 8354]]},
#   {'lightheadedness': [4, [8357, 8372]]},
#   {'dizziness': [3, [8376, 8385]]},
#   {'bleeding': [3, [8387, 8395]]},
#   {'swelling': [5, [8397, 8405]]},
#   {'pain': [3, [8410, 8414]]},
#   {'procedure': [5, [8423, 8432]]},
#   {'groin': [6, [8446, 8451]]}],
#  '18914188-DS-20': [{'Abdominal pain': [4, [274, 288]]},
#   {'Laparoscopic cholecystectomy': [2, [330, 358]]},
#   {'epigastric': [4, [416, 426]]},
#   {'abd pain': [4, [427, 435]]},
#   {'biliary \nobstruction': [4, [547, 567]]},
#   {'asymptomatic': [3, [614, 626]]},
#   {'biliary colic': [4, [657, 670]]},
#   {'fever': [3, [681, 686]]},
#   {'chills': [4, [690, 696]]},
#   {'chest pain': [4, [702, 712]]},
#   {'SOB': [3, [716, 719]]},
#   {'blood with bowel movements': [4, [752, 778]]},
#   {'hemorrhoids': [4, [803, 814]]},
#   {'colonoscopy': [1, [825, 836]]},
#   {'Cardiac arrest': [4, [884, 898]]},
#   {'AICD placed': [2, [914, 925]]},
#   {'atrial fibrillation': [4, [941, 960]]},
#   {'Hypertension': [3, [979, 991]]},
#   {'Pre-cancerous': [4, [996, 1009]]},
#   {'facial': [5, [1010, 1016]]},
#   {'lesions': [5, [1017, 1024]]},
#   {'Appendectomy': [2, [1029, 1041]]},
#   {'CABG': [1, [1045, 1049]]},
#   {'Hyperlipidemia': [3, [1054, 1068]]},
#   {'PE': [3, [1129, 1131]]},
#   {'RA': [3, [1152, 1154]]},
#   {'Ox4': [4, [1157, 1160]]},
#   {'NAD': [3, [1162, 1165]]},
#   {'RRR': [4, [1166, 1169]]},
#   {'CTAB': [4, [1171, 1175]]},
#   {'Abd soft': [4, [1176, 1184]]},
#   {'hernias': [4, [1189, 1196]]},
#   {'Ext': [1, [1197, 1200]]},
#   {'edema': [3, [1204, 1209]]},
#   {'LFTs': [4, [1301, 1305]]},
#   {'UA': [1, [1379, 1381]]},
#   {'RUQ': [6, [1449, 1452]]},
#   {'US': [1, [1453, 1455]]},
#   {'gallstones': [4, [1476, 1486]]},
#   {'distended': [4, [1494, 1503]]},
#   {'gallbladder': [5, [1504, 1515]]},
#   {'wall': [5, [1528, 1532]]},
#   {'thickening': [3, [1534, 1544]]},
#   {'edema': [3, [1549, 1554]]},
#   {'NPO': [2, [1569, 1572]]},
#   {'medications were \ngiven': [2, [1577, 1600]]},
#   {'pain control': [2, [1605, 1617]]},
#   {'surgery': [1, [1663, 1670]]},
#   {'surgery': [1, [1825, 1832]]},
#   {'laparoscopic \ncholecystectomy': [2, [1839, 1868]]},
#   {'PACU': [2, [1908, 1912]]},
#   {'clear liquids': [2, [1950, 1963]]},
#   {'regular diet': [4, [1995, 2007]]},
#   {'IV': [1, [2028, 2030]]},
#   {'pain control': [2, [2045, 2057]]},
#   {'hemodynamically stable': [4, [2075, 2097]]},
#   {'Neuro': [1, [2100, 2105]]},
#   {'IV fluids': [2, [2142, 2151]]},
#   {'pain control': [2, [2183, 2195]]},
#   {'CV': [1, [2199, 2201]]},
#   {'stable': [3, [2224, 2230]]},
#   {'vital signs were routinely monitored': [2, [2266, 2302]]},
#   {'stable': [3, [2337, 2343]]},
#   {'vital signs were routinely monitored': [2, [2374, 2410]]},
#   {'pulmonary \ntoilet': [2, [2417, 2434]]},
#   {'ambulation': [2, [2442, 2452]]},
#   {'incentive spirrometry': [2, [2457, 2478]]},
#   {'Post-operatively': [4, [2536, 2552]]},
#   {'clear \ndiet': [4, [2582, 2593]]},
#   {'regular diet': [4, [2623, 2635]]},
#   {'white blood count': [2, [2658, 2675]]},
#   {'fever': [1, [2680, 2685]]},
#   {'watched for': [2, [2707, 2718]]},
#   {'signs of infection': [2, [2719, 2737]]},
#   {'blood sugar was monitored': [2, [2766, 2791]]},
#   {'complete blood count': [2, [2882, 2902]]},
#   {'transfusions': [1, [2931, 2943]]},
#   {'Prophylaxis': [1, [2960, 2971]]},
#   {'ambulate': [2, [3093, 3101]]},
#   {'afebrile': [4, [3179, 3187]]},
#   {'stable vital signs': [4, [3194, 3212]]},
#   {'a': [4, [3241, 3242]]},
#   {'regular \ndiet': [4, [3243, 3256]]},
#   {'ambulating': [4, [3258, 3268]]},
#   {'voiding without assistance': [4, [3270, 3296]]},
#   {'pain was well \ncontrolled': [4, [3302, 3327]]},
#   {'teaching': [1, [3360, 3368]]},
#   {'instructions': [1, [3384, 3396]]},
#   {'discharge plan': [2, [3451, 3465]]},
#   {'Choledocholithiasis': [4, [4554, 4573]]},
#   {'Acute cholecystitis': [4, [4577, 4596]]},
#   {'good condition': [4, [4635, 4649]]},
#   {'regular diet': [4, [4663, 4675]]},
#   {'oral': [1, [4680, 4684]]},
#   {'pain medications': [2, [4686, 4702]]},
#   {'bowel': [5, [4717, 4722]]},
#   {'chest pain': [4, [4892, 4902]]},
#   {'pressure': [3, [4904, 4912]]},
#   {'squeezing': [4, [4914, 4923]]},
#   {'tightness': [4, [4928, 4937]]},
#   {'cough': [3, [4958, 4963]]},
#   {'shortness of breath': [4, [4965, 4984]]},
#   {'wheeze': [4, [4989, 4995]]},
#   {'vomiting': [3, [5010, 5018]]},
#   {'keep': [4, [5030, 5034]]},
#   {'fluids': [4, [5040, 5046]]},
#   {'dehydrated': [3, [5087, 5097]]},
#   {'vomiting': [3, [5115, 5123]]},
#   {'diarrhea': [3, [5125, 5133]]},
#   {'Signs': [3, [5154, 5159]]},
#   {'dehydration': [3, [5163, 5174]]},
#   {'dry mouth': [4, [5183, 5192]]},
#   {'rapid \nheartbeat': [4, [5194, 5210]]},
#   {'dizzy': [4, [5223, 5228]]},
#   {'faint when': [4, [5232, 5242]]},
#   {'standing': [3, [5243, 5251]]},
#   {'blood': [3, [5263, 5268]]},
#   {'dark/black material': [4, [5272, 5291]]},
#   {'vomit': [4, [5301, 5306]]},
#   {'bowel movement': [4, [5318, 5332]]},
#   {'burning': [3, [5351, 5358]]},
#   {'you urinate': [4, [5364, 5375]]},
#   {'blood in your \nurine': [4, [5382, 5402]]},
#   {'discharge': [5, [5420, 5429]]},
#   {'pain': [3, [5438, 5442]]},
#   {'pain': [3, [5545, 5549]]},
#   {'chest': [5, [5606, 5611]]},
#   {'back': [5, [5616, 5620]]},
#   {'shaking': [3, [5633, 5640]]},
#   {'chills': [4, [5641, 5647]]},
#   {'fever': [3, [5652, 5657]]},
#   {'ambulate': [2, [5996, 6004]]},
#   {'drink adequate amounts of fluids': [2, [6033, 6065]]},
#   {'while taking pain \nmedications': [2, [6195, 6225]]},
#   {'increased pain': [4, [6304, 6318]]},
#   {'swelling': [5, [6320, 6328]]},
#   {'redness': [4, [6330, 6337]]},
#   {'drainage': [5, [6342, 6350]]},
#   {'incision \nsite': [6, [6360, 6374]]},
#   {'surgical incisions': [6, [6464, 6482]]},
#   {'weight': [3, [6781, 6787]]}],
#  '10797747-DS-20': [{'Compazine': [4, [196, 205]]},
#   {'Post dates pregnancy': [4, [253, 273]]},
#   {'induction of\nlabor': [2, [396, 414]]},
#   {'cervix': [5, [436, 442]]},
#   {'URI': [4, [537, 540]]},
#   {'AFM': [3, [659, 662]]},
#   {'CP': [3, [667, 669]]},
#   {'SOB': [3, [670, 673]]},
#   {'wheeze': [4, [674, 680]]},
#   {'HA': [3, [685, 687]]},
#   {'visual\nchanges': [4, [688, 702]]},
#   {'RUQ pain': [4, [703, 711]]},
#   {'u/s': [2, [763, 766]]},
#   {'RPR': [4, [798, 801]]},
#   {'HBsAg': [3, [805, 810]]},
#   {'GBS': [3, [812, 815]]},
#   {'unk\n-': [2, [816, 821]]},
#   {'S': [2, [824, 825]]},
#   {'pregnancy': [3, [894, 903]]},
#   {'ultrasound': [1, [918, 928]]},
#   {'ultrasound': [1, [959, 969]]},
#   {'uterus': [5, [1017, 1023]]},
#   {'uncomplicated': [3, [1041, 1054]]},
#   {'trauma': [3, [1096, 1102]]},
#   {'ultrasound': [1, [1116, 1126]]},
#   {'crack cocaine': [4, [1185, 1198]]},
#   {'pregnancy': [3, [1212, 1221]]},
#   {'domestic violence': [4, [1239, 1256]]},
#   {'pre-eclampsia': [4, [1263, 1276]]},
#   {'pregnancy': [3, [1288, 1297]]},
#   {'SVD': [4, [1354, 1357]]},
#   {'pre-E': [4, [1363, 1368]]},
#   {'SVD': [4, [1379, 1382]]},
#   {'SAB': [3, [1388, 1391]]},
#   {'abnl': [4, [1463, 1467]]},
#   {'pap': [1, [1468, 1471]]},
#   {'LSIL': [2, [1473, 1477]]},
#   {'Asthma': [3, [1522, 1528]]},
#   {'intubation': [1, [1546, 1556]]},
#   {'ADD': [3, [1615, 1618]]},
#   {'ADHD': [3, [1619, 1623]]},
#   {'depression': [3, [1625, 1635]]},
#   {'anxiety': [3, [1637, 1644]]},
#   {'PTSD': [3, [1646, 1650]]},
#   {'bipolar': [3, [1653, 1660]]},
#   {'suicide attempts': [4, [1676, 1692]]},
#   {'Pulmonary nodule': [4, [1695, 1711]]},
#   {'PPD': [3, [1713, 1716]]},
#   {'tonsillectomy': [2, [1755, 1768]]},
#   {'drainage': [3, [1771, 1779]]},
#   {'abscess': [5, [1780, 1787]]},
#   {'R elbow': [6, [1788, 1795]]},
#   {'VS': [3, [1898, 1900]]},
#   {'RA': [3, [1925, 1927]]},
#   {'NARD': [4, [1941, 1945]]},
#   {'RRR': [4, [1946, 1949]]},
#   {'CTAB': [4, [1950, 1954]]},
#   {'wheezes': [4, [1958, 1965]]},
#   {'bronchial breath sounds': [4, [1972, 1995]]},
#   {'Abd': [3, [1996, 1999]]},
#   {'soft': [3, [2000, 2004]]},
#   {'gravid': [4, [2006, 2012]]},
#   {'nontender': [4, [2013, 2022]]},
#   {'Ext': [1, [2037, 2040]]},
#   {'NT': [3, [2041, 2043]]},
#   {'edema': [3, [2047, 2052]]},
#   {'FH': [3, [2071, 2073]]},
#   {'WBC': [1, [2139, 2142]]},
#   {'RBC': [1, [2149, 2152]]},
#   {'Hgb': [2, [2159, 2162]]},
#   {'Hct': [1, [2168, 2171]]},
#   {'MCH': [1, [2186, 2189]]},
#   {'MCHC': [2, [2195, 2199]]},
#   {'RDW': [2, [2205, 2208]]},
#   {'WBC': [1, [2240, 2243]]},
#   {'RBC': [1, [2250, 2253]]},
#   {'Hgb': [2, [2260, 2263]]},
#   {'Hct': [1, [2270, 2273]]},
#   {'MCH': [1, [2288, 2291]]},
#   {'MCHC': [2, [2297, 2301]]},
#   {'RDW': [2, [2307, 2310]]},
#   {'Neuts': [2, [2342, 2347]]},
#   {'Monos': [1, [2358, 2363]]},
#   {'Eos': [1, [2368, 2371]]},
#   {'o': [2, [2380, 2381]]},
#   {'Glucose': [1, [2404, 2411]]},
#   {'UreaN': [2, [2415, 2420]]},
#   {'Creat': [2, [2424, 2429]]},
#   {'Na': [1, [2434, 2436]]},
#   {'Cl': [1, [2448, 2450]]},
#   {'HCO3': [1, [2455, 2459]]},
#   {'AnGap': [2, [2464, 2469]]},
#   {'Protein': [1, [2513, 2520]]},
#   {'Ketone': [1, [2537, 2543]]},
#   {'pH': [1, [2570, 2572]]},
#   {'URINE': [1, [2599, 2604]]},
#   {'Protein': [1, [2627, 2634]]},
#   {'Ketone': [1, [2652, 2658]]},
#   {'pH': [1, [2686, 2688]]},
#   {'induction of \nlabor': [2, [2775, 2794]]},
#   {'induction': [1, [2816, 2825]]},
#   {'born infant': [4, [2872, 2883]]},
#   {'post-partum': [4, [2913, 2924]]},
#   {'pani': [4, [3006, 3010]]},
#   {'well controlled': [4, [3015, 3030]]},
#   {'regular diet': [4, [3065, 3077]]},
#   {'-up': [4, [3131, 3134]]},
#   {'vaginal delivery': [4, [3467, 3483]]},
#   {'stable': [3, [3508, 3514]]}],
#  '16464652-DS-17': [{'No': [3, [176, 178]]},
#   {'Adverse Drug Reactions': [4, [197, 219]]},
#   {'abdominal pain': [4, [257, 271]]},
#   {'diarrhea': [3, [273, 281]]},
#   {'DVT': [3, [388, 391]]},
#   {'hyponatremia': [4, [393, 405]]},
#   {'chronic \npancreatic abnormalitiy': [4, [411, 443]]},
#   {'lower abdominal pain': [4, [481, 501]]},
#   {'diarrhea': [3, [506, 514]]},
#   {'diarrhea': [3, [541, 549]]},
#   {'abdominal pain': [4, [610, 624]]},
#   {'constant': [3, [633, 641]]},
#   {'nonr': [3, [644, 648]]},
#   {'ating': [4, [651, 656]]},
#   {'lower central abdomen': [6, [669, 690]]},
#   {'abdominal \npain': [4, [696, 711]]},
#   {'diarrhea': [3, [755, 763]]},
#   {'movement': [4, [798, 806]]},
#   {'passing gas': [4, [839, 850]]},
#   {'able to eat and drink': [4, [864, 885]]},
#   {'fevers': [4, [899, 905]]},
#   {'chills': [4, [907, 913]]},
#   {'vomiting': [3, [915, 923]]},
#   {'hematemesis': [4, [925, 936]]},
#   {'melena': [4, [938, 944]]},
#   {'hematochezia': [4, [946, 958]]},
#   {'travel': [3, [961, 967]]},
#   {'food ingestion': [4, [984, 998]]},
#   {'.': [2, [1034, 1035]]},
#   {'urinary \nhesitancy': [4, [1071, 1089]]},
#   {'dysuria': [4, [1094, 1101]]},
#   {'alcohol use': [4, [1124, 1135]]},
#   {'smoke': [3, [1142, 1147]]},
#   {'vitals': [4, [1202, 1208]]},
#   {'ra': [3, [1247, 1249]]},
#   {'Exam': [1, [1251, 1255]]},
#   {'ttp': [3, [1281, 1284]]},
#   {'rebound': [3, [1290, 1297]]},
#   {'guarding': [4, [1298, 1306]]},
#   {'Labs': [1, [1308, 1312]]},
#   {'crea': [2, [1363, 1367]]},
#   {'WBC': [1, [1382, 1385]]},
#   {'CT abdomen': [2, [1392, 1402]]},
#   {'pancreatitis': [3, [1411, 1423]]},
#   {'splenic vein \nthrombosis': [4, [1459, 1483]]},
#   {'pancreatitis': [3, [1633, 1645]]},
#   {'VS': [3, [1647, 1649]]},
#   {'RA': [3, [1693, 1695]]},
#   {'abdominal pain': [4, [1728, 1742]]},
#   {'lower abdomen': [6, [1794, 1807]]},
#   {'ating': [4, [1816, 1821]]},
#   {'vomiting': [3, [1839, 1847]]},
#   {'fevers': [4, [1849, 1855]]},
#   {'chills': [4, [1857, 1863]]},
#   {'SOB': [3, [1868, 1871]]},
#   {'weight loss': [4, [1902, 1913]]},
#   {'poor appetite': [4, [1939, 1952]]},
#   {'constipation': [3, [2001, 2013]]},
#   {'hyponatremia': [4, [2064, 2076]]},
#   {'pancreatic \nabnormality': [4, [2109, 2132]]},
#   {'biopsy': [1, [2157, 2163]]},
#   {'colonoscopy': [1, [2165, 2176]]},
#   {'endoscopy': [1, [2183, 2192]]},
#   {'DVT': [3, [2209, 2212]]},
#   {'chronic lower abdominal pain': [4, [2270, 2298]]},
#   {'testicular pain': [4, [2324, 2339]]},
#   {'fever': [3, [2364, 2369]]},
#   {'chills': [4, [2371, 2377]]},
#   {'night sweats': [4, [2379, 2391]]},
#   {'vision \nchanges': [4, [2393, 2408]]},
#   {'shortness of breath': [4, [2411, 2430]]},
#   {'chest pain': [4, [2432, 2442]]},
#   {'vomiting': [3, [2444, 2452]]},
#   {'BRBPR': [4, [2454, 2459]]},
#   {'melena': [4, [2462, 2468]]},
#   {'hematochezia': [4, [2470, 2482]]},
#   {'dysuria': [4, [2484, 2491]]},
#   {'hematuria': [3, [2493, 2502]]},
#   {'headache': [3, [2516, 2524]]},
#   {'pancreatic mass': [4, [2551, 2566]]},
#   {'biopsy': [1, [2571, 2577]]},
#   {'colonoscopy': [1, [2579, 2590]]},
#   {'endoscopy': [1, [2596, 2605]]},
#   {'endoscopy': [1, [2624, 2633]]},
#   {'H pylori gastritis': [4, [2641, 2659]]},
#   {'triple therapy': [2, [2664, 2678]]},
#   {'DVT': [3, [2692, 2695]]},
#   {'Diabetes Mellitus': [4, [2703, 2720]]},
#   {'pancreatic': [3, [2826, 2836]]},
#   {'GI disease': [4, [2846, 2856]]},
#   {'cancer': [5, [2859, 2865]]},
#   {'autoimmune disease': [4, [2870, 2888]]},
#   {'Physical Exam': [2, [2940, 2953]]},
#   {'VS': [3, [2977, 2979]]},
#   {'Temp': [4, [2982, 2986]]},
#   {'BP': [3, [2994, 2996]]},
#   {'HR': [3, [3005, 3007]]},
#   {'O2-sat': [2, [3019, 3025]]},
#   {'RA': [3, [3030, 3032]]},
#   {'General': [1, [3035, 3042]]},
#   {'NAD': [3, [3044, 3047]]},
#   {'HEENT': [2, [3069, 3074]]},
#   {'normocephalic': [4, [3076, 3089]]},
#   {'scleral icterus': [4, [3094, 3109]]},
#   {'OP clear': [4, [3111, 3119]]},
#   {'Neck': [1, [3122, 3126]]},
#   {'supple': [3, [3128, 3134]]},
#   {'cervical': [5, [3139, 3147]]},
#   {'CV': [1, [3153, 3155]]},
#   {'regular rhymthm': [4, [3158, 3173]]},
#   {'tachycardic': [4, [3175, 3186]]},
#   {'S2': [3, [3194, 3196]]},
#   {'no': [3, [3198, 3200]]},
#   {'r/m/g': [4, [3201, 3206]]},
#   {'Lungs': [1, [3221, 3226]]},
#   {'CTAB': [4, [3228, 3232]]},
#   {'rales': [4, [3237, 3242]]},
#   {'Abdomen': [1, [3243, 3250]]},
#   {'+BS': [4, [3252, 3255]]},
#   {'Soft': [3, [3256, 3260]]},
#   {'nondistended': [4, [3261, 3273]]},
#   {'tender to': [4, [3274, 3283]]},
#   {'palpation': [1, [3284, 3293]]},
#   {'lower abdomen': [6, [3310, 3323]]},
#   {'epigastric regions': [6, [3328, 3346]]},
#   {'lower \nabdomen': [6, [3357, 3371]]},
#   {"'s signs": [4, [3392, 3400]]},
#   {'negative': [3, [3401, 3409]]},
#   {'fluid': [5, [3415, 3420]]},
#   {'hepatosplenomegaly': [4, [3431, 3449]]},
#   {'rebound': [3, [3454, 3461]]},
#   {'guarding': [4, [3465, 3473]]},
#   {'GU': [1, [3475, 3477]]},
#   {'Fol': [1, [3482, 3485]]},
#   {'LAD': [3, [3492, 3495]]},
#   {'testicular': [5, [3499, 3509]]},
#   {'pain': [3, [3510, 3514]]},
#   {'palpation': [1, [3518, 3527]]},
#   {'CV': [1, [3532, 3534]]},
#   {'tenderness': [3, [3537, 3547]]},
#   {'Ext': [1, [3549, 3552]]},
#   {'WWP': [4, [3554, 3557]]},
#   {'+2 pulses': [4, [3559, 3568]]},
#   {'edema': [3, [3579, 3584]]},
#   {'Neuro': [1, [3587, 3592]]},
#   {'A': [3, [3594, 3595]]},
#   {'Ox3': [4, [3596, 3599]]},
#   {'attentive': [4, [3601, 3610]]},
#   {'Memory intact': [4, [3612, 3625]]},
#   {'Motor and sensory \nfunction grossly intact': [4, [3627, 3669]]},
#   {'Skin': [1, [3671, 3675]]},
#   {'rashes': [4, [3680, 3686]]},
#   {'spider angiomata': [4, [3691, 3707]]},
#   {'Physical Exam': [2, [3742, 3755]]},
#   {'VS': [3, [3778, 3780]]},
#   {'RA': [3, [3802, 3804]]},
#   {'General': [1, [3805, 3812]]},
#   {'NAD': [3, [3814, 3817]]},
#   {'HEENT': [2, [3839, 3844]]},
#   {'scleral icterus': [4, [3849, 3864]]},
#   {'CV': [1, [3866, 3868]]},
#   {'regular rhythm': [4, [3870, 3884]]},
#   {'normal rate': [4, [3886, 3897]]},
#   {'S1': [3, [3899, 3901]]},
#   {'S2 clear': [4, [3906, 3914]]},
#   {'no': [3, [3937, 3939]]},
#   {'r/m/g': [4, [3940, 3945]]},
#   {'Lungs': [1, [3959, 3964]]},
#   {'CTAB': [4, [3966, 3970]]},
#   {'good air movement': [4, [3988, 4005]]},
#   {'Abdomen': [1, [4008, 4015]]},
#   {'+BS': [4, [4017, 4020]]},
#   {'Soft': [3, [4022, 4026]]},
#   {'non-tender': [4, [4028, 4038]]},
#   {'distended': [4, [4049, 4058]]},
#   {'rebound': [3, [4063, 4070]]},
#   {'guarding': [4, [4075, 4083]]},
#   {'Extremities': [1, [4085, 4096]]},
#   {'Warm': [3, [4098, 4102]]},
#   {'well perfused': [4, [4107, 4120]]},
#   {'2+ DP pulses': [4, [4126, 4138]]},
#   {'cyanosis': [4, [4144, 4152]]},
#   {'edema': [3, [4154, 4159]]},
#   {'excoriations': [6, [4164, 4176]]},
#   {'Neuro': [1, [4178, 4183]]},
#   {'Ox3': [4, [4187, 4190]]},
#   {'attentive': [4, [4192, 4201]]},
#   {'WBC': [1, [4319, 4322]]},
#   {'RBC': [1, [4327, 4330]]},
#   {'Hgb': [2, [4337, 4340]]},
#   {'Hct': [1, [4347, 4350]]},
#   {'MCH': [1, [4364, 4367]]},
#   {'MCHC': [2, [4373, 4377]]},
#   {'RDW': [2, [4384, 4387]]},
#   {'Neuts': [2, [4419, 4424]]},
#   {'Monos': [1, [4434, 4439]]},
#   {'Eos': [1, [4444, 4447]]},
#   {'Baso': [2, [4453, 4457]]},
#   {'Glucose': [1, [4506, 4513]]},
#   {'UreaN': [2, [4519, 4524]]},
#   {'Creat': [2, [4528, 4533]]},
#   {'Na': [1, [4539, 4541]]},
#   {'Cl': [1, [4553, 4555]]},
#   {'HCO3': [1, [4559, 4563]]},
#   {'AnGap': [2, [4567, 4572]]},
#   {'Glucose': [1, [4594, 4601]]},
#   {'UreaN': [2, [4607, 4612]]},
#   {'Creat': [2, [4615, 4620]]},
#   {'Na': [1, [4625, 4627]]},
#   {'Cl': [1, [4640, 4642]]},
#   {'HCO3': [1, [4646, 4650]]},
#   {'AnGap': [2, [4654, 4659]]},
#   {'ALT': [1, [4681, 4684]]},
#   {'AST': [1, [4689, 4692]]},
#   {'AlkPhos': [2, [4696, 4703]]},
#   {'TotBili': [2, [4707, 4714]]},
#   {'Calcium': [1, [4767, 4774]]},
#   {'Phos': [2, [4779, 4783]]},
#   {'Mg': [1, [4788, 4790]]},
#   {'Albumin': [1, [4813, 4820]]},
#   {'Calcium': [1, [4825, 4832]]},
#   {'Phos': [2, [4837, 4841]]},
#   {'Mg': [1, [4846, 4848]]},
#   {'Imaging': [1, [4934, 4941]]},
#   {'CT Abd': [2, [4959, 4965]]},
#   {'Pelv': [2, [4966, 4970]]},
#   {'Pancreatitis': [3, [5007, 5019]]},
#   {'body': [5, [5042, 5046]]},
#   {'tail of the \npancreas': [6, [5051, 5072]]},
#   {'pancreatic': [5, [5087, 5097]]},
#   {'edema': [3, [5164, 5169]]},
#   {'pancreatic': [5, [5183, 5193]]},
#   {'necrosis': [5, [5194, 5202]]},
#   {'pancreas': [5, [5276, 5284]]},
#   {'lesions': [5, [5305, 5312]]},
#   {'ancreatic': [6, [5342, 5351]]},
#   {'fluid collection': [6, [5352, 5368]]},
#   {'splenic vein': [6, [5375, 5387]]},
#   {'body': [5, [5465, 5469]]},
#   {'tail of the pancreas': [6, [5474, 5494]]},
#   {'ground glass nodules': [4, [5531, 5551]]},
#   {'lung\nbases': [6, [5569, 5579]]},
#   {'infection': [3, [5603, 5612]]},
#   {'chest CT': [2, [5663, 5671]]},
#   {'malignancy': [5, [5747, 5757]]},
#   {'Hct': [1, [5837, 5840]]},
#   {'Na': [1, [5865, 5867]]},
#   {'Cl': [1, [5879, 5881]]},
#   {'ALT': [1, [5903, 5906]]},
#   {'AST': [1, [5912, 5915]]},
#   {'AlkPhos': [2, [5920, 5927]]},
#   {'TotBili': [2, [5931, 5938]]},
#   {'DVT': [3, [6001, 6004]]},
#   {'hyponatremia': [4, [6006, 6018]]},
#   {'pancreatic mass': [4, [6025, 6040]]},
#   {'malignancy': [5, [6055, 6065]]},
#   {'pancreatitis': [3, [6083, 6095]]},
#   {'pancreatic mass': [4, [6109, 6124]]},
#   {'Pancreatitis': [3, [6131, 6143]]},
#   {'pancreatitis': [3, [6185, 6197]]},
#   {'pain control': [2, [6228, 6240]]},
#   {'NPO': [2, [6255, 6258]]},
#   {'intravenous fluids': [2, [6269, 6287]]},
#   {'Diet': [1, [6289, 6293]]},
#   {'pain resolved': [4, [6320, 6333]]},
#   {'toler': [3, [6361, 6366]]},
#   {'without pain': [4, [6389, 6401]]},
#   {'pancreatic enzymes': [2, [6411, 6429]]},
#   {'diarrhea': [3, [6435, 6443]]},
#   {'hemodynamically stable': [4, [6458, 6480]]},
#   {'Pancreatic mass': [4, [6499, 6514]]},
#   {'FNA biopsy': [2, [6516, 6526]]},
#   {'adenocarcinoma': [5, [6557, 6571]]},
#   {'neuroendocrine tumor': [4, [6579, 6599]]},
#   {'MRI': [1, [6629, 6632]]},
#   {'pancreatic ductal mass': [4, [6640, 6662]]},
#   {'PET': [1, [6667, 6670]]},
#   {'lungs': [5, [6691, 6696]]},
#   {'Chest CT': [2, [6698, 6706]]},
#   {'nodules': [5, [6712, 6719]]},
#   {'metastatic \ndisease': [4, [6734, 6753]]},
#   {'biopsy': [1, [6804, 6810]]},
#   {'biopsy': [1, [6927, 6933]]},
#   {'Hyponatremia': [4, [6957, 6969]]},
#   {'SIADH': [4, [6984, 6989]]},
#   {'low': [3, [6996, 6999]]},
#   {'euvolemia': [4, [7013, 7022]]},
#   {'elevated': [3, [7024, 7032]]},
#   {'sodium': [4, [7039, 7045]]},
#   {'improvement': [3, [7051, 7062]]},
#   {'fluid restriction': [2, [7079, 7096]]},
#   {'SIADH': [4, [7118, 7123]]},
#   {'improved': [3, [7165, 7173]]},
#   {'fluid restriction': [2, [7213, 7230]]},
#   {'neurologic symptoms': [4, [7242, 7261]]},
#   {'Splenic vein thrombosis': [4, [7304, 7327]]},
#   {'Imaging': [1, [7329, 7336]]},
#   {'splenic vein thrombosis': [4, [7366, 7389]]},
#   {'imaging': [1, [7416, 7423]]},
#   {'retroperitoneal lymph node biopsy': [2, [7570, 7603]]},
#   {'pancreatic mass': [4, [7632, 7647]]},
#   {'diarrhea': [3, [7775, 7783]]},
#   {'BPH': [3, [7815, 7818]]},
#   {'Hyponatremia': [4, [7829, 7841]]},
#   {'Pancreatitis': [3, [8875, 8887]]},
#   {'Pancreatic malignancy': [4, [8890, 8911]]},
#   {'Pancreatic cancer': [4, [8926, 8943]]},
#   {'Hyponatremia': [4, [8946, 8958]]},
#   {'Mental Status': [2, [8983, 8996]]},
#   {'Clear': [3, [8998, 9003]]},
#   {'Level of Consciousness': [2, [9018, 9040]]},
#   {'Alert': [3, [9042, 9047]]},
#   {'interactive': [3, [9052, 9063]]},
#   {'Activity Status': [4, [9065, 9080]]},
#   {'Ambulatory - Independent': [4, [9082, 9106]]},
#   {'abdominal pain': [4, [9193, 9207]]},
#   {'diarrhea': [3, [9213, 9221]]},
#   {'inflammation of your pancreas': [4, [9232, 9261]]},
#   {'fluids': [1, [9278, 9284]]},
#   {'pain medication': [2, [9289, 9304]]},
#   {'improved': [3, [9309, 9317]]},
#   {'tolerating \nfood and liquids by mouth': [4, [9328, 9365]]},
#   {'diarrhea': [3, [9438, 9446]]},
#   {'weight loss': [4, [9522, 9533]]},
#   {'cancer': [5, [9553, 9559]]},
#   {'biopsy of a': [2, [9589, 9600]]},
#   {'lymph node': [6, [9601, 9611]]},
#   {'procedure': [1, [9662, 9671]]},
#   {'tenderness': [3, [9766, 9776]]},
#   {'bladder': [5, [9789, 9796]]},
#   {'difficulty \ninitiating urination': [4, [9806, 9838]]},
#   {'medication': [1, [9866, 9876]]},
#   {'primary': [1, [9927, 9934]]},
#   {'biopsy': [1, [10098, 10104]]}],
#  '19476699-DS-25': [{'Penicillins': [4, [176, 187]]},
#   {'morphine': [3, [190, 198]]},
#   {'Imitrex': [4, [201, 208]]},
#   {'Bright Red Blood per Rectum': [4, [246, 273]]},
#   {'Esophagogastroduodenoscopy': [2, [314, 340]]},
#   {'Colonoscopy': [1, [343, 354]]},
#   {'HFpEF': [3, [436, 441]]},
#   {'mitral valve disease': [4, [443, 463]]},
#   {'MVR': [4, [479, 482]]},
#   {'warfarin resistance': [4, [512, 531]]},
#   {'CAD': [3, [538, 541]]},
#   {'HTN': [3, [543, 546]]},
#   {'HLD': [4, [548, 551]]},
#   {'DMII': [4, [553, 557]]},
#   {'COPD': [3, [559, 563]]},
#   {'pyloric channel ulcer': [4, [565, 586]]},
#   {'upper GIB': [4, [592, 601]]},
#   {'bright red blood per rectum': [4, [627, 654]]},
#   {'chronic diastolic heart failure': [4, [711, 742]]},
#   {'nausea, vomiting, diarrhea': [4, [814, 840]]},
#   {'right-sided lower abdominal pain': [4, [853, 885]]},
#   {'pain worsened': [4, [898, 911]]},
#   {'CT \nabdomen/pelvis': [2, [945, 963]]},
#   {'ileocolitis': [4, [984, 995]]},
#   {'abdominal pain': [4, [1178, 1192]]},
#   {'resolved': [3, [1193, 1201]]},
#   {'warfarin resistance': [4, [1259, 1278]]},
#   {'heparin': [1, [1478, 1485]]},
#   {'abdominal cramping': [4, [1556, 1574]]},
#   {'bright red blood per rectum': [4, [1601, 1628]]},
#   {'clots': [6, [1634, 1639]]},
#   {'bloody\nbowel movements': [4, [1713, 1735]]},
#   {'clots': [6, [1741, 1746]]},
#   {'lightheadedness': [4, [1763, 1778]]},
#   {'dizziness': [3, [1780, 1789]]},
#   {'chest pain': [4, [1791, 1801]]},
#   {'palpitations': [4, [1803, 1815]]},
#   {'shortness of breath': [4, [1817, 1836]]},
#   {'heparin': [1, [1842, 1849]]},
#   {'transfusion': [1, [1933, 1944]]},
#   {'transfusion': [1, [2072, 2083]]},
#   {'cra': [3, [2221, 2224]]},
#   {'mping': [4, [2224, 2229]]},
#   {'bilateral\nlower abdominal pain': [4, [2230, 2260]]},
#   {'pain': [3, [2267, 2271]]},
#   {'right-sided lower abdominal pain': [4, [2307, 2339]]},
#   {'nausea, vomiting': [4, [2383, 2399]]},
#   {'fevers': [4, [2404, 2410]]},
#   {'chills': [4, [2414, 2420]]},
#   {'substernal chest discomfort': [4, [2445, 2472]]},
#   {'anxiety': [3, [2496, 2503]]},
#   {'shortness \nof\nbreath': [4, [2549, 2569]]},
#   {'cough': [3, [2573, 2578]]},
#   {'Hypertension': [3, [2639, 2651]]},
#   {'Diabetes mellitus': [4, [2654, 2671]]},
#   {'Pulmonary Hypertension': [4, [2690, 2712]]},
#   {'Rheumatic heart disease': [4, [2724, 2747]]},
#   {'Paroxysmal Afib': [4, [2750, 2765]]},
#   {'Morbid obesity': [4, [2768, 2782]]},
#   {'Asthma': [3, [2785, 2791]]},
#   {'Chronic obstructive pulmonary disease': [4, [2794, 2831]]},
#   {'Migraines': [4, [2834, 2843]]},
#   {'Obstructive sleep apnea': [4, [2846, 2869]]},
#   {'Depression': [3, [2897, 2907]]},
#   {'Bipolar disorder': [4, [2908, 2924]]},
#   {'Fibromyalgia': [3, [2936, 2948]]},
#   {'Osteoarthritis': [3, [2963, 2977]]},
#   {'Bells Palsy': [4, [2991, 3002]]},
#   {'mechanical': [1, [3009, 3019]]},
#   {'mitral valve replacement': [2, [3020, 3044]]},
#   {'closure': [1, [3045, 3052]]},
#   {'resection': [1, [3068, 3077]]},
#   {'left atrial appendage': [6, [3078, 3099]]},
#   {'cervical spine': [6, [3133, 3147]]},
#   {'surgery': [1, [3148, 3155]]},
#   {'bleeding': [4, [3194, 3202]]},
#   {'C-section': [2, [3216, 3225]]},
#   {'fibromyalgia': [3, [3286, 3298]]},
#   {'ovarian': [3, [3353, 3360]]},
#   {'breast': [3, [3362, 3368]]},
#   {'colon cancer': [4, [3374, 3386]]},
#   {'Congenital heart disease': [4, [3406, 3430]]},
#   {'RHD': [4, [3453, 3456]]},
#   {'MVR': [4, [3461, 3464]]},
#   {'MI': [3, [3477, 3479]]},
#   {'stroke': [3, [3501, 3507]]},
#   {'PHYSICAL EXAM': [2, [3544, 3557]]},
#   {'VS': [3, [3584, 3586]]},
#   {'Ra': [3, [3609, 3611]]},
#   {'GEN': [1, [3613, 3616]]},
#   {'Alert': [3, [3618, 3623]]},
#   {'lying in bed': [4, [3625, 3637]]},
#   {'HEENT': [2, [3668, 3673]]},
#   {'Moist': [3, [3675, 3680]]},
#   {'anicteric sclerae': [6, [3685, 3702]]},
#   {'conjunctival pallor': [4, [3707, 3726]]},
#   {'right\npupil': [6, [3729, 3740]]},
#   {'reactive': [3, [3749, 3757]]},
#   {'left pupil': [6, [3759, 3769]]},
#   {'reactive': [3, [3779, 3787]]},
#   {'EOMI': [4, [3789, 3793]]},
#   {'NECK': [1, [3796, 3800]]},
#   {'Supple': [3, [3802, 3808]]},
#   {'LAD': [3, [3817, 3820]]},
#   {'neck veins': [4, [3822, 3832]]},
#   {'PULM': [2, [3840, 3844]]},
#   {'CTAB': [4, [3846, 3850]]},
#   {'no': [3, [3852, 3854]]},
#   {'w/r/r': [4, [3855, 3860]]},
#   {'COR': [1, [3861, 3864]]},
#   {'RRR': [4, [3866, 3869]]},
#   {'ABD': [1, [3890, 3893]]},
#   {'Obese': [3, [3895, 3900]]},
#   {'BS+': [4, [3902, 3905]]},
#   {'soft': [3, [3907, 3911]]},
#   {'tender': [3, [3923, 3929]]},
#   {'lower abdomen': [6, [3933, 3946]]},
#   {'rebound': [3, [3955, 3962]]},
#   {'guarding': [4, [3966, 3974]]},
#   {'EXTREM': [1, [3976, 3982]]},
#   {'Warm': [3, [3984, 3988]]},
#   {'well-perfused': [4, [3990, 4003]]},
#   {'pit': [5, [4008, 4011]]},
#   {'edema': [3, [4016, 4021]]},
#   {'SKIN': [1, [4022, 4026]]},
#   {'Venous stasis': [4, [4028, 4041]]},
#   {'lower extremities': [6, [4063, 4080]]},
#   {'NEURO': [1, [4083, 4088]]},
#   {'AO': [5, [4090, 4092]]},
#   {'CN II': [4, [4095, 4100]]},
#   {'XII': [4, [4101, 4104]]},
#   {'grossly intact': [4, [4105, 4119]]},
#   {'motor function grossly\nnormal': [4, [4121, 4150]]},
#   {'PSYCH': [1, [4151, 4156]]},
#   {'Anxious mood': [4, [4158, 4170]]},
#   {'affect': [3, [4175, 4181]]},
#   {'GEN': [1, [4236, 4239]]},
#   {'Alert': [3, [4241, 4246]]},
#   {'NECK': [1, [4310, 4314]]},
#   {'Supple': [3, [4316, 4322]]},
#   {'LAD': [3, [4331, 4334]]},
#   {'neck': [5, [4336, 4340]]},
#   {'PULM': [2, [4354, 4358]]},
#   {'CTAB': [4, [4360, 4364]]},
#   {'COR': [1, [4366, 4369]]},
#   {'RRR': [4, [4371, 4374]]},
#   {'ABD': [1, [4395, 4398]]},
#   {'Obese': [3, [4400, 4405]]},
#   {'BS+': [4, [4407, 4410]]},
#   {'soft': [3, [4412, 4416]]},
#   {'tenderness to palpation': [4, [4418, 4441]]},
#   {'RUQ': [6, [4445, 4448]]},
#   {'RLQ': [6, [4453, 4456]]},
#   {'rebound': [3, [4466, 4473]]},
#   {'guarding': [4, [4477, 4485]]},
#   {'EXTREM': [1, [4487, 4493]]},
#   {'Warm': [3, [4495, 4499]]},
#   {'well-perfused': [4, [4501, 4514]]},
#   {'pit': [5, [4519, 4522]]},
#   {'edema': [3, [4527, 4532]]},
#   {'SKIN': [1, [4535, 4539]]},
#   {'Venous stasis': [4, [4541, 4554]]},
#   {'lower extremities': [6, [4576, 4593]]},
#   {'PSYCH': [1, [4596, 4601]]},
#   {'Calm mood': [4, [4603, 4612]]},
#   {'affect': [3, [4617, 4623]]},
#   {'HGB': [2, [4691, 4694]]},
#   {'HCT': [2, [4704, 4707]]},
#   {'PTT': [1, [4729, 4732]]},
#   {'WBC': [1, [4757, 4760]]},
#   {'RBC': [1, [4765, 4768]]},
#   {'HGB': [2, [4775, 4778]]},
#   {'HCT': [1, [4784, 4787]]},
#   {'MCH': [1, [4802, 4805]]},
#   {'MCHC': [2, [4812, 4816]]},
#   {'RDW': [2, [4823, 4826]]},
#   {'RDWSD': [2, [4833, 4838]]},
#   {'ALT': [1, [4859, 4862]]},
#   {'AST': [1, [4872, 4875]]},
#   {'LDH': [1, [4888, 4891]]},
#   {'PHOS': [2, [4902, 4906]]},
#   {'TOT BILI': [2, [4912, 4920]]},
#   {'WBC': [1, [4977, 4980]]},
#   {'RBC': [1, [4985, 4988]]},
#   {'Hgb': [2, [4995, 4998]]},
#   {'Hct': [1, [5004, 5007]]},
#   {'MCH': [1, [5022, 5025]]},
#   {'MCHC': [2, [5032, 5036]]},
#   {'RDW': [2, [5043, 5046]]},
#   {'RDWSD': [2, [5053, 5058]]},
#   {'PTT': [1, [5095, 5098]]},
#   {'EGD': [2, [5110, 5113]]},
#   {'Normal mucosa': [4, [5130, 5143]]},
#   {'esophagus': [5, [5157, 5166]]},
#   {'Erosions': [6, [5169, 5177]]},
#   {'antrum': [6, [5185, 5191]]},
#   {'Normal mucosa': [4, [5194, 5207]]},
#   {'duodenum': [5, [5230, 5238]]},
#   {'COLONOSCOPY': [1, [5242, 5253]]},
#   {'colon': [5, [5360, 5365]]},
#   {'diverticulosis': [4, [5426, 5440]]},
#   {'sigmoid colon': [6, [5448, 5461]]},
#   {'No evidence': [4, [5464, 5475]]},
#   {'GI bleeding': [4, [5486, 5497]]},
#   {'HFpEF': [3, [5567, 5572]]},
#   {'mitral \nvalve disease': [4, [5574, 5595]]},
#   {'MVR': [4, [5611, 5614]]},
#   {'warfarin': [3, [5645, 5653]]},
#   {'CAD': [3, [5666, 5669]]},
#   {'HTN': [3, [5671, 5674]]},
#   {'HLD': [4, [5676, 5679]]},
#   {'DMII': [4, [5681, 5685]]},
#   {'COPD': [3, [5687, 5691]]},
#   {'bright red blood per rectum': [4, [5711, 5738]]},
#   {'Diverticulosis': [4, [5742, 5756]]},
#   {'GI bleed': [4, [5758, 5766]]},
#   {'acute blood loss': [4, [5768, 5784]]},
#   {'anemia': [3, [5785, 5791]]},
#   {'bright red blood per rectum': [4, [5816, 5843]]},
#   {'CT A/P': [2, [5845, 5851]]},
#   {'contrast': [2, [5858, 5866]]},
#   {'sigmoid diverticulosis': [4, [5888, 5910]]},
#   {'no \nevidence': [4, [5915, 5927]]},
#   {'bleeding': [3, [5938, 5946]]},
#   {'mechanical MVR': [4, [5977, 5991]]},
#   {'warfarin resistance': [4, [5996, 6015]]},
#   {'Hgb': [2, [6114, 6117]]},
#   {'Hgb': [2, [6127, 6130]]},
#   {'stable': [4, [6140, 6146]]},
#   {'blood transfusion': [2, [6192, 6209]]},
#   {'EGD': [2, [6246, 6249]]},
#   {'antral': [5, [6278, 6284]]},
#   {'erosions': [6, [6285, 6293]]},
#   {'colonoscopy': [1, [6299, 6310]]},
#   {'diverticulosis': [4, [6336, 6350]]},
#   {'bleeding': [3, [6365, 6373]]},
#   {'bleeding': [3, [6495, 6503]]},
#   {'Abdominal Pain': [4, [6597, 6611]]},
#   {'cramping abdominal pain': [4, [6628, 6651]]},
#   {'antibiotics': [1, [6670, 6681]]},
#   {'ileocolitis': [4, [6686, 6697]]},
#   {'resolution': [3, [6702, 6712]]},
#   {'pain': [3, [6726, 6730]]},
#   {'CT': [1, [6732, 6734]]},
#   {'signs': [3, [6752, 6757]]},
#   {'colitis': [3, [6769, 6776]]},
#   {'pain': [3, [6813, 6817]]},
#   {'Pain': [3, [6819, 6823]]},
#   {'pain regimen': [2, [6912, 6924]]},
#   {'opioid \nuse disorder': [4, [6970, 6990]]},
#   {'Opioid Use Disorder': [4, [6994, 7013]]},
#   {'osteoarthritis': [3, [7071, 7085]]},
#   {'divorce': [4, [7154, 7161]]},
#   {'loneliness': [3, [7166, 7176]]},
#   {'helplessness': [4, [7196, 7208]]},
#   {'pain': [3, [7285, 7289]]},
#   {'Mitral Regurgitation': [4, [7445, 7465]]},
#   {'Mechanical MVR': [4, [7470, 7484]]},
#   {'warfarin': [3, [7492, 7500]]},
#   {'Paroxysmal Afib': [4, [7950, 7965]]},
#   {'normal sinus rhythm': [4, [7978, 7997]]},
#   {'HFpEF': [3, [8066, 8071]]},
#   {'Euvolemic': [4, [8073, 8082]]},
#   {'Chest Pain': [4, [8159, 8169]]},
#   {'single-vessel CAD': [4, [8193, 8210]]},
#   {'atypical chest pain': [4, [8238, 8257]]},
#   {'Pain': [3, [8259, 8263]]},
#   {'exertional': [4, [8272, 8282]]},
#   {'normal': [3, [8289, 8295]]},
#   {'ekg': [2, [8296, 8299]]},
#   {'negative enzymes': [4, [8304, 8320]]},
#   {'Resolved': [3, [8323, 8331]]},
#   {'Chest pain': [4, [8354, 8364]]},
#   {'free': [3, [8365, 8369]]},
#   {'CAD': [3, [8408, 8411]]},
#   {'COPD': [3, [8477, 8481]]},
#   {'No evidence': [4, [8483, 8494]]},
#   {'exacerbation': [4, [8504, 8516]]},
#   {'HTN': [3, [8537, 8540]]},
#   {'BP': [1, [8547, 8549]]},
#   {'DMII': [4, [8576, 8580]]},
#   {'Anxiety': [3, [8665, 8672]]},
#   {'Obstructive Sleep Apnea': [4, [8700, 8723]]},
#   {'CPAP': [1, [8735, 8739]]},
#   {'OA': [3, [8753, 8755]]},
#   {'the': [4, [8759, 8762]]},
#   {'R knee': [6, [8763, 8769]]},
#   {'otics': [2, [9134, 9139]]},
#   {'pain relief': [2, [9144, 9155]]},
#   {'.': [2, [9217, 9218]]},
#   {'Diverticulosis': [4, [11914, 11928]]},
#   {'anemia': [3, [11943, 11949]]},
#   {'Mental Status': [2, [11973, 11986]]},
#   {'Clear': [3, [11988, 11993]]},
#   {'Level of Consciousness': [2, [12008, 12030]]},
#   {'Alert': [3, [12032, 12037]]},
#   {'interactive': [3, [12042, 12053]]},
#   {'Activity': [3, [12055, 12063]]},
#   {'Ambulatory - requires assistance or aid': [4, [12072, 12111]]},
#   {'bleeding': [3, [12285, 12293]]},
#   {'GI \ntract': [4, [12302, 12311]]},
#   {'endoscopy': [1, [12367, 12376]]},
#   {'colonoscopy': [1, [12381, 12392]]},
#   {'bleeding': [3, [12425, 12433]]},
#   {'procedure': [1, [12472, 12481]]},
#   {'bleeding': [3, [12515, 12523]]}],
#  '11436844-DS-4': [{'fall': [3, [234, 238]]},
#   {'CAD': [3, [323, 326]]},
#   {'CABG': [1, [331, 335]]},
#   {'colon': [5, [345, 350]]},
#   {'surgeries': [1, [351, 360]]},
#   {'trauma': [3, [399, 405]]},
#   {'rib \nfractures': [4, [421, 435]]},
#   {'fall': [3, [454, 458]]},
#   {'fell': [3, [553, 557]]},
#   {'right side': [6, [567, 577]]},
#   {'LOC': [3, [586, 589]]},
#   {'laceration to': [4, [621, 634]]},
#   {'R forearm': [6, [639, 648]]},
#   {'CT \nhead': [2, [678, 686]]},
#   {'tors': [5, [688, 692]]},
#   {'abdomen': [1, [695, 702]]},
#   {'CXR': [2, [704, 707]]},
#   {'x-ray': [2, [712, 717]]},
#   {'R hand': [6, [718, 724]]},
#   {'non-displaced': [6, [741, 754]]},
#   {'fractures': [5, [755, 764]]},
#   {'ribs': [6, [779, 783]]},
#   {'right': [5, [787, 792]]},
#   {'evaluation': [1, [800, 810]]},
#   {'NAD': [3, [854, 857]]},
#   {'breathing well': [4, [866, 880]]},
#   {'on room air': [4, [881, 892]]},
#   {'pain': [3, [972, 976]]},
#   {'right flank': [6, [988, 999]]},
#   {'CHF': [3, [1031, 1034]]},
#   {'CODP': [4, [1036, 1040]]},
#   {'CKD': [3, [1042, 1045]]},
#   {'anemia': [3, [1047, 1053]]},
#   {'Physical Exam': [2, [1137, 1150]]},
#   {'R ribs': [6, [1153, 1159]]},
#   {'rib 9': [6, [1207, 1212]]},
#   {'flail chest': [4, [1218, 1229]]},
#   {'ecchymosis': [4, [1234, 1244]]},
#   {'Lungs clear': [4, [1246, 1257]]},
#   {'exam': [1, [1306, 1310]]},
#   {'Head': [1, [1312, 1316]]},
#   {'NCAT': [2, [1317, 1321]]},
#   {'R forearm': [6, [1323, 1332]]},
#   {'skin': [5, [1365, 1369]]},
#   {'VS': [3, [1397, 1399]]},
#   {'BP': [3, [1412, 1414]]},
#   {'Sitting': [3, [1425, 1432]]},
#   {'HR': [3, [1433, 1435]]},
#   {'RR': [3, [1440, 1442]]},
#   {'Ra': [3, [1455, 1457]]},
#   {'GEN': [1, [1459, 1462]]},
#   {'A': [3, [1464, 1465]]},
#   {'Ox3': [4, [1466, 1469]]},
#   {'NAD': [3, [1471, 1474]]},
#   {'HEENT': [2, [1475, 1480]]},
#   {'atraumatic': [4, [1482, 1492]]},
#   {'MMM': [4, [1494, 1497]]},
#   {'CV': [1, [1498, 1500]]},
#   {'RRR': [4, [1502, 1505]]},
#   {'PULM': [2, [1506, 1510]]},
#   {'CTA': [3, [1512, 1515]]},
#   {'ABD': [1, [1520, 1523]]},
#   {'soft': [3, [1525, 1529]]},
#   {'non-distended': [4, [1531, 1544]]},
#   {'non-tender': [4, [1546, 1556]]},
#   {'palpation': [1, [1560, 1569]]},
#   {'EXT': [1, [1570, 1573]]},
#   {'wwp': [4, [1575, 1578]]},
#   {'edema': [3, [1586, 1591]]},
#   {'UE': [6, [1596, 1598]]},
#   {'RUE': [6, [1601, 1604]]},
#   {'abrasions': [2, [1605, 1614]]},
#   {'Right Hand': [6, [1664, 1674]]},
#   {'x-ray': [2, [1675, 1680]]},
#   {'No acute': [4, [1698, 1706]]},
#   {'CT Chest': [2, [1735, 1743]]},
#   {'nondisplaced': [6, [1773, 1785]]},
#   {'fractures': [5, [1786, 1795]]},
#   {'right': [5, [1811, 1816]]},
#   {'9th ribs': [6, [1830, 1838]]},
#   {'CT abd/pelvis': [2, [1844, 1857]]},
# ...
#   {'stenosis': [5, [1146, 1154]]},
#   {'midcircum': [6, [1162, 1171]]},
#   {'flex': [5, [1171, 1175]]},
#   {'RCA': [5, [1177, 1180]]},
#   {'ost': [5, [1191, 1194]]},
#   {'stenosis': [5, [1198, 1206]]},
#   {'obtuse marginal': [6, [1214, 1229]]},
#   {'stenosis': [5, [1242, 1250]]},
#   {'RCA': [5, [1252, 1255]]},
#   {'stenosis': [5, [1278, 1286]]},
#   {'intervention': [1, [1358, 1370]]},
#   {'valve repair': [2, [1389, 1401]]},
#   {'worsening': [3, [1450, 1459]]},
#   {'transfer to \nthe ICU': [2, [1516, 1536]]},
#   {'intubated': [2, [1538, 1547]]},
#   {'mechanically ventilated': [2, [1552, 1575]]},
#   {'acute on \nchronic systolic heart failure': [4, [1580, 1620]]},
#   {'Chest x-ray': [2, [1622, 1633]]},
#   {'acute pulmonary edema': [4, [1651, 1672]]},
#   {'left heart \ncath': [2, [1762, 1778]]},
#   {'Lasix': [2, [1801, 1806]]},
#   {'hypotensive': [4, [1837, 1848]]},
#   {'-': [4, [1853, 1854]]},
#   {'intubation': [1, [1854, 1864]]},
#   {'infusion': [1, [1879, 1887]]},
#   {'tachycardia': [3, [1902, 1913]]},
#   {'UTI': [3, [2025, 2028]]},
#   {'pneumonia': [3, [2033, 2042]]},
#   {'intubated': [2, [2254, 2263]]},
#   {'sedated': [4, [2268, 2275]]},
#   {'CARDIAC RISK FACTORS': [2, [2343, 2363]]},
#   {'Diabetes': [3, [2366, 2374]]},
#   {'Hypertension': [3, [2383, 2395]]},
#   {'Dyslipidemia': [3, [2404, 2416]]},
#   {'Mid LAD': [6, [2457, 2464]]},
#   {'stenosis': [5, [2470, 2478]]},
#   {'RCA': [5, [2481, 2484]]},
#   {'stenosis': [5, [2490, 2498]]},
#   {'LCx': [6, [2500, 2503]]},
#   {'Lesion': [5, [2506, 2512]]},
#   {'CX': [1, [2520, 2522]]},
#   {'stenosis': [5, [2528, 2536]]},
#   {'Lesion': [5, [2539, 2545]]},
#   {'stenosis': [5, [2573, 2581]]},
#   {'Lesion': [5, [2584, 2590]]},
#   {'stenosis': [5, [2618, 2626]]},
#   {'Chronic systolic congestive heart failure': [4, [2636, 2677]]},
#   {'Rhythm': [3, [2680, 2686]]},
#   {'NSR': [4, [2688, 2691]]},
#   {'Chronic systolic congestive heart failure': [4, [2755, 2796]]},
#   {'Hypertension': [3, [2797, 2809]]},
#   {'Diabetes': [3, [2810, 2818]]},
#   {'Diabetic neuropathy': [4, [2819, 2838]]},
#   {'Dyslipidemia': [3, [2839, 2851]]},
#   {'Restless leg syndrome': [4, [2852, 2873]]},
#   {'skin cancer': [4, [2885, 2896]]},
#   {'stomach cancer': [4, [2917, 2931]]},
#   {'Spinal stenosis': [4, [2932, 2947]]},
#   {'died': [3, [2994, 2998]]},
#   {'heart attack': [4, [3020, 3032]]},
#   {'died': [3, [3040, 3044]]},
#   {'old': [3, [3063, 3066]]},
#   {'died': [3, [3080, 3084]]},
#   {'lung cancer': [4, [3101, 3112]]},
#   {'VS': [3, [3146, 3148]]},
#   {'BP': [3, [3157, 3159]]},
#   {'HR': [3, [3168, 3170]]},
#   {'RR': [3, [3174, 3176]]},
#   {'O2 SAT': [2, [3180, 3186]]},
#   {'GENERAL': [1, [3231, 3238]]},
#   {'Intubated': [2, [3240, 3249]]},
#   {'sedated': [4, [3251, 3258]]},
#   {'HEENT': [2, [3260, 3265]]},
#   {'Normocephalic': [4, [3267, 3280]]},
#   {'atraumatic': [4, [3281, 3291]]},
#   {'Sclera anicteric': [4, [3293, 3309]]},
#   {'PERRL': [4, [3311, 3316]]},
#   {'NECK': [1, [3319, 3323]]},
#   {'Supple': [3, [3325, 3331]]},
#   {'JVP': [4, [3333, 3336]]},
#   {'elevated': [4, [3344, 3352]]},
#   {'lying': [3, [3354, 3359]]},
#   {'R': [5, [3367, 3368]]},
#   {'CARDIAC': [1, [3382, 3389]]},
#   {'intercostal space': [6, [3410, 3427]]},
#   {'midclavicular \nline': [6, [3429, 3448]]},
#   {'Regular rate and rhythm': [4, [3450, 3473]]},
#   {'Normal S1': [4, [3475, 3484]]},
#   {'S2': [3, [3486, 3488]]},
#   {'systolic': [3, [3494, 3502]]},
#   {'murmur': [4, [3504, 3510]]},
#   {'LUSB': [6, [3522, 3526]]},
#   {'LUNGS': [1, [3528, 3533]]},
#   {'chest wall deformities': [4, [3538, 3560]]},
#   {'tenderness': [3, [3564, 3574]]},
#   {'unlabored': [4, [3592, 3601]]},
#   {'rales': [4, [3624, 3629]]},
#   {'bases': [5, [3633, 3638]]},
#   {'wheezes': [4, [3643, 3650]]},
#   {'rhonchi': [4, [3655, 3662]]},
#   {'ABDOMEN': [1, [3664, 3671]]},
#   {'Soft': [3, [3673, 3677]]},
#   {'non-tender': [4, [3679, 3689]]},
#   {'non-distended': [4, [3691, 3704]]},
#   {'hepatomegaly': [4, [3709, 3721]]},
#   {'splenomegaly': [3, [3727, 3739]]},
#   {'Bruise': [4, [3741, 3747]]},
#   {'heparin injections': [2, [3760, 3778]]},
#   {'flanks': [6, [3782, 3788]]},
#   {'umbilicus': [6, [3794, 3803]]},
#   {'EXTREMITIES': [1, [3805, 3816]]},
#   {'Warm': [3, [3818, 3822]]},
#   {'well perfused': [4, [3824, 3837]]},
#   {'clubbing': [6, [3842, 3850]]},
#   {'cyanosis': [4, [3852, 3860]]},
#   {'edema': [3, [3882, 3887]]},
#   {'ankles': [6, [3891, 3897]]},
#   {'SKIN': [1, [3900, 3904]]},
#   {'skin': [3, [3921, 3925]]},
#   {'lesions': [5, [3926, 3933]]},
#   {'rashes': [4, [3937, 3943]]},
#   {'pulses': [3, [3960, 3966]]},
#   {'palpable': [4, [3971, 3979]]},
#   {'Right IJ': [6, [4004, 4012]]},
#   {'deceased': [3, [4052, 4060]]},
#   {'O2 SAT': [2, [4171, 4177]]},
#   {'URINE': [1, [4193, 4198]]},
#   {'COLOR': [3, [4200, 4205]]},
#   {'NITRITE-NEG': [4, [4261, 4272]]},
#   {'PROTEIN': [1, [4273, 4280]]},
#   {'GLUCOSE-NEG': [4, [4285, 4296]]},
#   {'KETONE-NEG': [4, [4297, 4307]]},
#   {'BILIRUBIN-NEG': [4, [4308, 4321]]},
#   {'N-NEG': [4, [4330, 4335]]},
#   {'PH': [1, [4336, 4338]]},
#   {'LEUK-NEG': [4, [4344, 4352]]},
#   {'URINE': [1, [4365, 4370]]},
#   {'RBC': [1, [4372, 4375]]},
#   {'WBC': [1, [4379, 4382]]},
#   {'URINE': [1, [4428, 4433]]},
#   {'GLUCOSE': [1, [4521, 4528]]},
#   {'N': [2, [4539, 4540]]},
#   {'CREAT': [2, [4545, 4550]]},
#   {'SODIUM': [1, [4556, 4562]]},
#   {'POTASSIUM': [1, [4568, 4577]]},
#   {'CHLORIDE': [1, [4582, 4590]]},
#   {'TOTAL CO2': [2, [4594, 4603]]},
#   {'ANION GAP': [2, [4607, 4616]]},
#   {'ALT': [1, [4666, 4669]]},
#   {'AST': [1, [4682, 4685]]},
#   {'PHOS': [2, [4728, 4732]]},
#   {'TOT BILI': [2, [4737, 4745]]},
#   {'cTropnT': [2, [4772, 4779]]},
#   {'ALBUMIN': [1, [4800, 4807]]},
#   {'CALCIUM': [1, [4813, 4820]]},
#   {'WBC': [1, [4870, 4873]]},
#   {'RBC': [1, [4880, 4883]]},
#   {'HGB': [2, [4890, 4893]]},
#   {'HCT': [1, [4899, 4902]]},
#   {'MCH': [1, [4917, 4920]]},
#   {'MCHC': [2, [4926, 4930]]},
#   {'RDW': [2, [4937, 4940]]},
#   {'RDWSD': [2, [4946, 4951]]},
#   {'PTT': [1, [5004, 5007]]},
#   {'PH': [1, [5057, 5059]]},
#   {'TOTAL \nCO2': [2, [5065, 5075]]},
#   {'WBC': [1, [5125, 5128]]},
#   {'RBC': [1, [5135, 5138]]},
#   {'Hgb': [2, [5145, 5148]]},
#   {'Hct': [1, [5154, 5157]]},
#   {'MCH': [1, [5172, 5175]]},
#   {'MCHC': [2, [5181, 5185]]},
#   {'RDW': [2, [5192, 5195]]},
#   {'RDWSD': [2, [5202, 5207]]},
#   {'Neuts': [2, [5240, 5245]]},
#   {'Lymphs': [2, [5258, 5264]]},
#   {'Monos': [1, [5268, 5273]]},
#   {'Baso': [2, [5285, 5289]]},
#   {'Glucose': [1, [5612, 5619]]},
#   {'UreaN': [2, [5625, 5630]]},
#   {'Creat': [2, [5635, 5640]]},
#   {'Na': [1, [5646, 5648]]},
#   {'Cl': [1, [5660, 5662]]},
#   {'HCO3': [1, [5666, 5670]]},
#   {'AnGap': [2, [5675, 5680]]},
#   {'ALT': [1, [5702, 5705]]},
#   {'AST': [1, [5711, 5714]]},
#   {'AlkPhos': [2, [5735, 5742]]},
#   {'TotBili': [2, [5747, 5754]]},
#   {'Calcium': [1, [5778, 5785]]},
#   {'Phos': [2, [5791, 5795]]},
#   {'Mg': [1, [5801, 5803]]},
#   {'pH': [1, [5929, 5931]]},
#   {'hypertension': [3, [6075, 6087]]},
#   {'hyperlipidemia': [3, [6089, 6103]]},
#   {'chronic systolic heart failure': [4, [6106, 6136]]},
#   {'valvular heart disease': [4, [6138, 6160]]},
#   {'exertional dyspnea': [4, [6193, 6211]]},
#   {'three vessel disease': [4, [6242, 6262]]},
#   {'LHC': [2, [6266, 6269]]},
#   {'pulmonary edema': [4, [6282, 6297]]},
#   {'intubation': [1, [6308, 6318]]},
#   {'PCI': [1, [6351, 6354]]},
#   {'LHC': [2, [6378, 6381]]},
#   {'DES': [1, [6397, 6400]]},
#   {'LAD': [5, [6408, 6411]]},
#   {'posturing': [4, [6430, 6439]]},
#   {'seizure': [3, [6477, 6484]]},
#   {'stroke': [3, [6489, 6495]]},
#   {'CT \nhead': [2, [6511, 6519]]},
#   {'MRI': [1, [6527, 6530]]},
#   {'EEG': [1, [6562, 6565]]},
#   {'no': [3, [6573, 6575]]},
#   {'seizure': [3, [6591, 6598]]},
#   {'pressors': [2, [6636, 6644]]},
#   {'septic': [3, [6676, 6682]]},
#   {'cardiogenic shock': [4, [6683, 6700]]},
#   {'MR': [3, [6716, 6718]]},
#   {'HCAP': [4, [6723, 6727]]},
#   {'antibiotics': [1, [6768, 6779]]},
#   {'diuresis': [2, [6795, 6803]]},
#   {'fevers': [4, [6853, 6859]]},
#   {'Imaging': [1, [6884, 6891]]},
#   {'atrial \nfibrillation': [4, [6945, 6965]]},
#   {'anticoagulated': [2, [7004, 7018]]},
#   {'Mechanical ventilation': [2, [7020, 7042]]},
#   {'respirations': [4, [7098, 7110]]},
#   {'ventilation support': [2, [7125, 7144]]},
#   {'pressors': [2, [7172, 7180]]},
#   {'Shock': [3, [7747, 7752]]},
#   {'cardiogenic': [4, [7760, 7771]]},
#   {'septic': [3, [7773, 7779]]},
#   {'Fevers': [4, [7782, 7788]]},
#   {'Hypoxic resp failure': [4, [7815, 7835]]},
#   {'thoracic': [5, [7842, 7850]]},
#   {'Acute on chronic systolic CHF': [4, [7879, 7908]]},
#   {'Lasix': [2, [7928, 7933]]},
#   {'HCAP': [4, [7938, 7942]]},
#   {'Toxic metabolic encephalopathy': [4, [7981, 8011]]},
#   {'Hyponatremia': [4, [8014, 8026]]},
#   {'Congestive': [3, [8030, 8040]]},
#   {'Hepatopathy': [4, [8041, 8052]]},
#   {'AFib w/ RVR': [4, [8055, 8066]]},
#   {'stable': [3, [8096, 8102]]},
#   {'Deceased': [3, [8127, 8135]]},
#   {'': [4, [0, 0]]}],
#  '15906604-DS-2': [{'No': [3, [183, 185]]},
#   {'Adverse Drug Reactions': [4, [204, 226]]},
#   {'Chest pain': [4, [264, 274]]},
#   {'cocaine abuse': [4, [377, 390]]},
#   {'chest pain': [4, [416, 426]]},
#   {'sharp': [3, [460, 465]]},
#   {'sternal': [4, [470, 477]]},
#   {'chest pain': [4, [479, 489]]},
#   {'radiating': [4, [513, 522]]},
#   {'worse': [3, [524, 529]]},
#   {'Pain': [3, [554, 558]]},
#   {'constant': [3, [568, 576]]},
#   {'pain': [3, [601, 605]]},
#   {'chest wall injuries': [4, [625, 644]]},
#   {'EKG': [2, [704, 707]]},
#   {'STE': [3, [714, 717]]},
#   {'negative': [3, [778, 786]]},
#   {'trop': [1, [788, 792]]},
#   {'Pain': [3, [819, 823]]},
#   {'ev': [1, [910, 912]]},
#   {'vitals': [4, [937, 943]]},
#   {'Labs': [1, [973, 977]]},
#   {'WBC': [1, [999, 1002]]},
#   {'Troponin': [1, [1009, 1017]]},
#   {'IV': [1, [1063, 1065]]},
#   {'Vitals': [4, [1082, 1088]]},
#   {'improvement': [3, [1150, 1161]]},
#   {'chest pain': [4, [1165, 1175]]},
#   {'fever': [3, [1194, 1199]]},
#   {'chills': [4, [1201, 1207]]},
#   {'cough': [3, [1209, 1214]]},
#   {'SOB': [3, [1216, 1219]]},
#   {'orthopnea': [4, [1221, 1230]]},
#   {'MGF': [4, [1302, 1305]]},
#   {'CAD': [3, [1307, 1310]]},
#   {'cirrhosis': [3, [1319, 1328]]},
#   {'lung cancer': [4, [1337, 1348]]},
#   {'VS': [3, [1378, 1380]]},
#   {'BP': [3, [1389, 1391]]},
#   {'HR': [3, [1399, 1401]]},
#   {'RR': [3, [1405, 1407]]},
#   {'O2 sat': [2, [1411, 1417]]},
#   {'RA': [3, [1422, 1424]]},
#   {'General': [1, [1427, 1434]]},
#   {'Well developed': [4, [1436, 1450]]},
#   {'NAD': [3, [1459, 1462]]},
#   {'HEENT': [2, [1464, 1469]]},
#   {'EOMI': [4, [1471, 1475]]},
#   {'PERRL': [4, [1477, 1482]]},
#   {'sclera anicteric': [4, [1484, 1500]]},
#   {'Neck': [1, [1502, 1506]]},
#   {'JVP not elevated': [4, [1508, 1524]]},
#   {'supple': [3, [1526, 1532]]},
#   {'LAD': [3, [1537, 1540]]},
#   {'CV': [1, [1542, 1544]]},
#   {'RRR': [4, [1546, 1549]]},
#   {'normal S1 and': [4, [1551, 1564]]},
#   {'S2': [3, [1565, 1567]]},
#   {'no mrg': [4, [1569, 1575]]},
#   {'Chest wall': [6, [1577, 1587]]},
#   {'tender': [3, [1598, 1604]]},
#   {'palpation': [1, [1609, 1618]]},
#   {'left': [5, [1624, 1628]]},
#   {'right margins': [6, [1633, 1646]]},
#   {'sternum': [6, [1650, 1657]]},
#   {'xyphoid \nprocess': [6, [1662, 1678]]},
#   {'Lungs': [1, [1680, 1685]]},
#   {'CTAB': [4, [1687, 1691]]},
#   {'wheezes': [4, [1696, 1703]]},
#   {'rales': [4, [1707, 1712]]},
#   {'Abdomen': [1, [1714, 1721]]},
#   {'Soft': [3, [1723, 1727]]},
#   {'nontender': [4, [1729, 1738]]},
#   {'non-distended': [4, [1740, 1753]]},
#   {'organomegaly': [4, [1768, 1780]]},
#   {'GU': [1, [1782, 1784]]},
#   {'Ext': [1, [1797, 1800]]},
#   {'Warm': [3, [1802, 1806]]},
#   {'well perfused': [4, [1808, 1821]]},
#   {'edema': [3, [1826, 1831]]},
#   {'2+ DP pulses': [4, [1833, 1845]]},
#   {'General': [1, [1859, 1866]]},
#   {'Well developed': [4, [1868, 1882]]},
#   {'NAD': [3, [1891, 1894]]},
#   {'HEENT': [2, [1896, 1901]]},
#   {'EOMI': [4, [1903, 1907]]},
#   {'PERRL': [4, [1909, 1914]]},
#   {'sclera anicteric': [4, [1916, 1932]]},
#   {'Neck': [1, [1934, 1938]]},
#   {'JVP not elevated': [4, [1940, 1956]]},
#   {'supple': [3, [1958, 1964]]},
#   {'LAD': [3, [1969, 1972]]},
#   {'CV': [1, [1974, 1976]]},
#   {'RRR': [4, [1978, 1981]]},
#   {'normal S1 and': [4, [1983, 1996]]},
#   {'S2': [3, [1997, 1999]]},
#   {'no mr': [4, [2001, 2006]]},
#   {'g': [2, [2006, 2007]]},
#   {'Chest wall': [6, [2009, 2019]]},
#   {'tender': [3, [2030, 2036]]},
#   {'palpation': [1, [2041, 2050]]},
#   {'left': [5, [2056, 2060]]},
#   {'right margins': [6, [2065, 2078]]},
#   {'sternum': [6, [2082, 2089]]},
#   {'xyphoid \nprocess': [6, [2094, 2110]]},
#   {'Lungs': [1, [2112, 2117]]},
#   {'CTAB': [4, [2119, 2123]]},
#   {'wheezes': [4, [2128, 2135]]},
#   {'rales': [4, [2139, 2144]]},
#   {'Abdomen': [1, [2146, 2153]]},
#   {'Soft': [3, [2155, 2159]]},
#   {'nontender': [4, [2161, 2170]]},
#   {'non-distended': [4, [2172, 2185]]},
#   {'organomegaly': [4, [2200, 2212]]},
#   {'GU': [1, [2214, 2216]]},
#   {'Ext': [1, [2229, 2232]]},
#   {'Warm': [3, [2234, 2238]]},
#   {'well perfused': [4, [2240, 2253]]},
#   {'edema': [3, [2258, 2263]]},
#   {'2+ DP pulses': [4, [2265, 2277]]},
#   {'WBC': [1, [2330, 2333]]},
#   {'RBC': [1, [2340, 2343]]},
#   {'Hgb': [2, [2349, 2352]]},
#   {'Hct': [1, [2358, 2361]]},
#   {'MCH': [1, [2375, 2378]]},
#   {'MCHC': [2, [2384, 2388]]},
#   {'RDW': [2, [2394, 2397]]},
#   {'Neuts': [2, [2429, 2434]]},
#   {'Lymphs': [2, [2441, 2447]]},
#   {'Monos': [1, [2453, 2458]]},
#   {'Eos': [1, [2463, 2466]]},
#   {'Glucose': [1, [2499, 2506]]},
#   {'UreaN': [2, [2510, 2515]]},
#   {'Creat': [2, [2519, 2524]]},
#   {'Na': [1, [2529, 2531]]},
#   {'Cl': [1, [2543, 2545]]},
#   {'HCO3': [1, [2550, 2554]]},
#   {'AnGap': [2, [2558, 2563]]},
#   {'cTropnT': [2, [2614, 2621]]},
#   {'Calcium': [1, [2672, 2679]]},
#   {'Phos': [2, [2684, 2688]]},
#   {'Mg': [1, [2694, 2696]]},
#   {'Echo': [1, [2720, 2724]]},
#   {'Normal biventricular regional/global systolic \nfunction': [4,
#     [2742, 2797]]},
#   {'No evidence': [4, [2815, 2826]]},
#   {'acute aortic syndrome': [4, [2830, 2851]]},
#   {'Heart': [5, [2858, 2863]]},
#   {'size': [3, [2864, 2868]]},
#   {'normal': [3, [2876, 2882]]},
#   {'dilated right atrium': [4, [2890, 2910]]},
#   {'pericardial \neffusion': [4, [2917, 2938]]},
#   {'consolidation': [5, [2956, 2969]]},
#   {'nodules': [5, [2996, 3003]]},
#   {'bronchiolitis': [4, [3031, 3044]]},
#   {'smoking': [3, [3063, 3070]]},
#   {'Mild': [3, [3082, 3086]]},
#   {'paraseptal emphysema': [4, [3087, 3107]]},
#   {'cTropnT': [2, [3145, 3152]]},
#   {'cocaine abuse': [4, [3182, 3195]]},
#   {'chest pain': [4, [3221, 3231]]},
#   {'Chest Pain': [4, [3236, 3246]]},
#   {'costochondtritis': [4, [3260, 3276]]},
#   {'musculoskeletal pain': [4, [3291, 3311]]},
#   {'Pain': [3, [3313, 3317]]},
#   {'angina': [3, [3334, 3340]]},
#   {'exertion': [3, [3373, 3381]]},
#   {'CAD': [3, [3472, 3475]]},
#   {'cocaine use': [4, [3493, 3504]]},
#   {'CTA': [1, [3506, 3509]]},
#   {'aortic dissection': [4, [3529, 3546]]},
#   {'PE': [3, [3551, 3553]]},
#   {'troponin': [1, [3558, 3566]]},
#   {'normal': [3, [3595, 3601]]},
#   {'ECHO': [1, [3611, 3615]]},
#   {'ECG': [1, [3638, 3641]]},
#   {'ST elevations': [4, [3662, 3675]]},
#   {'normal': [3, [3708, 3714]]},
#   {'pain was': [4, [3777, 3785]]},
#   {'improved': [3, [3786, 3794]]},
#   {'pain': [1, [3881, 3885]]},
#   {'Hypophosphatemia': [4, [3914, 3930]]},
#   {'MI': [3, [4053, 4055]]},
#   {'negative': [3, [4061, 4069]]},
#   {'trop x3': [2, [4070, 4077]]},
#   {'EKG': [2, [4079, 4082]]},
#   {'ord': [6, [4095, 4098]]},
#   {'J-point elevation': [4, [4102, 4119]]},
#   {'normal': [3, [4133, 4139]]},
#   {'PCP': [1, [4274, 4277]]},
#   {'Chest pain': [4, [4985, 4995]]},
#   {'Mental Status': [2, [5020, 5033]]},
#   {'Clear': [3, [5035, 5040]]},
#   {'Level of Consciousness': [2, [5055, 5077]]},
#   {'Alert': [3, [5079, 5084]]},
#   {'interactive': [3, [5089, 5100]]},
#   {'Activity Status': [4, [5102, 5117]]},
#   {'Ambulatory - Independent': [4, [5119, 5143]]},
#   {'chest pain': [4, [5216, 5226]]},
#   {'physical examination': [2, [5243, 5263]]},
#   {'EKG': [2, [5265, 5268]]},
#   {'ultrasound of your heart': [2, [5270, 5294]]},
#   {'blood \ntests': [2, [5299, 5311]]},
#   {'chest pain': [4, [5337, 5347]]},
#   {'heart \nattack': [4, [5364, 5377]]},
#   {'pain': [3, [5384, 5388]]},
#   {'inflammation': [3, [5401, 5413]]},
#   {'muscles': [5, [5421, 5428]]},
#   {'cartilage': [5, [5433, 5442]]},
#   {'inflammation': [3, [5511, 5523]]},
#   {'primary care': [2, [5544, 5556]]}]}

# %%
# pred_annotations
# data = json.dumps(pred_annotations)
# with open("7label_pred.json", "w") as file:
#     json.dump(data, file)

# %%
print(score_dict['microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext'])
# Out:
#               precision    recall  f1-score   support
#
#         FIND       0.75      0.81      0.78      3310
#         PROC       0.76      0.74      0.75      2227
#       STRUCT       0.56      0.76      0.65       580
#
#    micro avg       0.73      0.78      0.76      6117
#    macro avg       0.69      0.77      0.73      6117
# weighted avg       0.74      0.78      0.76      6117

# %%
# model.save_pretrained('7label_NER_Final')
